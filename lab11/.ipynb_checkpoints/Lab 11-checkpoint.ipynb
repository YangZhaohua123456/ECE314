# %% [markdown]
# # Lab 11: ODEs, Failure Rates, and Evolutionary Games

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
import scipy as sp
import scipy.stats as st
from scipy.integrate import odeint
print ('Modules Imported!')
# Out:
# Modules Imported!

# %% [markdown]
# In this lab we're to going analyze evolutionary games using drift analysis. In order to do this, we first need to determine how to integrate ordinary differential equations. So, we begin with a brief exposure of how to achieve this in Python. While we're at it, we'll do a short exercise about failure rate functions.  Then we examine some evolutionary games, using both a stochastic model and a deterministic model, which involves the differential equations.

# %% [markdown]
# ## Integration of ODEs

# %% [markdown]
# This section gives an introdution to integrating ordinary differential equations (odes), with an application to the calculation of a CDF from a failure rate function.  If you recall from your math classes we can describe an ODE as the following:
#
# $\dot{y}=f(y),$
#
# where both $y$ and the function $f$ are vector valued, and $\dot{y}$ is shorthand for $\frac{dy}{dt}.$   The variables being vector valued simply implies that we could have a system of dependent one dimensional (1D) ODEs as opposed to just a single one dimensional variable.  Let's look at the following system:
#
# \begin{eqnarray*}
# \binom{\dot{y_0}}{\dot{y_1}} = \binom{2y_1-0.1y_0}{-y_0}
# \end{eqnarray*}
# with the initial condition $y_{init}=\binom{y_1(0)}{y_2(0)}=\binom{1}{1}.$
#
# Our goal in using Python is not to find a closed form solution to the ODE as you would have probably done in your math class, but to numerically integrate it and produce a graphical solution. In order to do this we use the odeint method from scipy.integrate. It takes a function with an initial value and specified times at which the solution is to be output. Internally, the numerical method will often use a much finer grid of time points to solve the ode -- but that is none of your concern.   The times you put in are the times at with the method needs to provide the values of the solution. Look how it is used below:

# %%
# Simple example integrating a 2d ordinary differential equation (ode) dy/dt=f(y,t) 
# Note that the odeint package is imported in the code at the beginning of this file.

# Function to integrate over
def f(y,t):    
    return np.array([2.*y[1]-.1*y[0],-y[0] ])

time=np.linspace(0.0,20.0,10000)   # The times at which the solution is output.
yinit=np.array([1.0,1.0])   # The initial condition
y=odeint(f,yinit,time)      

plt.plot(y[:,0],y[:,1])
plt.title('trajectory of y up to time 20')
plt.ylabel('y_1')
plt.xlabel('y_0')
# Out:
# Text(0.5, 0, 'y_0')

# %% [markdown]
# Typically in a plot like this you would add an arrow to indicate the direction of time in the graph. However, we know the initial state is $y_{init}=\binom{1}{1}.$ So as time increases, the trajectory moves concentrically inwards in a clockwise fashion. Depending on how much of differential equations you remember, this solution should make sense. The equation happens to have a linear form and can be written as $\dot y = Ay$ where
# $
# A=\left( \begin{array}{cc}  -0.1  &  2  \\  -1  & 0 \end{array} \right).
# $
# The eigenvalues of $A$ are complex with negative real parts, so we would expect a decaying oscillatory behavior. (If you didn't follow that, don't worry about it.)
#
# As a simple application of integrating a 1D (one-dimensional) ode, the following code calculates a CDF $F$ from its failure rate function $h.$ But first, let's look at some theory to remember what a failure rate function is. If we let $T$ be a positive random variable with a pdf $f_T$ then
# the failure rate function is defined by the following:
#
# $$h(t)=\lim_{\epsilon \to 0} \frac{P(t<T \leq t+\epsilon | T>t)}{\epsilon}$$
#
# Equivalently, an object having failure rate function $h$ means that for any $t > 0,$ given
# that the object is still working at time $t$, the probability it will fail in the next
# $\epsilon$ time units is $h(t)\epsilon + o(\epsilon)$.  (As usual, $o(\epsilon)$ represents an error term such that $o(\epsilon)/\epsilon \to 0$ as $\epsilon\to 0.$)  With a little bit more derivation (shown in Section 3.9 of your ECE 313 text), we can see that:
#
# $$h(t) = \frac{f_T(t)}{1-F_T(t)}$$
#
# Of course, the pdf $f_T$ is the derivative of the CDF $F_T$. Here's where your 1D ODE comes into play. Given a failure rate function, we want to be able to calculate the CDF. We can easily turn this into an ODE.
#
# $f_T(t) = (1-F_T(t))h(t)$
#
# Let $F_T(t) = y$ and  $f_T(t) = \frac{dy}{dt} = \dot{y}$, then:
#
# $\dot{y} = (1-y)h(t)$
#
# Now we have our differential equation set up and we can solve it by the same method used in the previous example. For the code below, we define a particular bathtub shaped failure rate function to model the lifetime of a component such as a hard disk drive. There is a high, but decreasing initial rate of failure, followed be a period with a very low rate failure, followed by an increasing rate of failure. You should be able to think of reasons why an object might exhibit this type of failure rate function. Notice that the CDF behaves as we would expect: always between 0 and 1, and reactive to $h(t)$.
#
# If you examine the ECE 313 notes you'll see another way to determine $F_T,$  namely, using
# $F_T(t) = 1- \exp \left( \int_o^t -h(s) ds \right)$.  The point here, though, is to get some practice using
# odeint, instead of using this formula.

# %%
# Calculation of CDF from its failure rate function, using dF/dt=(1-F(t))h(t)
from scipy.integrate import odeint

def h(t):   # h is the failure rate function with a bathtub shape
    if t<1:
        return 1-t
    elif t<3:
        return 0.0
    else:
        return np.sqrt(t-3)
    

def Fdot(y,t):    
    return (1-y)*h(t)

t_max=8.0  #  Select so that F(t_max) is very close to one
time=np.linspace(0.0,t_max,1000)
Finit=0.0
F=odeint(Fdot,Finit,time)
plt.plot(time,list(map(h,time)))
plt.text(4,h(4)+0.5, r'$h(t)$',fontsize=24) #Plots labels in the graph
plt.text(4,0.5, r'$F(t)$',fontsize=24) 

plt.plot(time,F)
plt.title('failure rate function $h$ and associated CDF, $F$')
plt.axis(ymin=0,ymax=2.0)
plt.ylabel('$h(t), F(t)$',fontsize=20)
plt.xlabel('$t$',fontsize=20)
# Out:
# Text(0.5, 0, '$t$')

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 1:</SPAN>** Using the information on failure rate functions and the example above, do the following:
# <ol>
# <li> Write code that, given the failure rate function of a random variable $T$, computes the mean lifetime, $E[T].$  Use this code to determine the mean lifetime for the example given above.  (Hint: An easy way to do this problem is to use the area rule for expectations. Since $T$ is nonnegative, the area rule for expectations gives $E[T]=\int_0^\infty(1-F(t)) dt.$
# The integral $\int_0^\infty (1-F(t)) dt$ is approximately equal to
# $\int_0^{t_{max}} (1-F(t)) dt,$  which, by the definition of Riemann integration, is approximately equal to
# $h \sum_{i=1}^{1000} (1-F(h_i)) $ where $h=t_{max}/1000.$  Basically the code above returns the samples $F(h_i)$ so all you need to do is subtract these values from 1, sum them up and multiply by $h$.)
# <li> What happens to $E[T]$ if the failure rate function is doubled for all time? Print out the new value of $E[T]$.
# </ol>

# %%
# Your code here
t_max=8
time=np.linspace(0.0,t_max,1000)
Finit=0.0
F=odeint(Fdot,Finit,time)
def cal_mean(F):
    sum = 0
    for i in range(1000):
        sum+=1-F[i][0]
    return 8/1000*sum
mean_1 = cal_mean(F)
print('E[T]:',mean_1)
def new_h(t):   # h is the failure rate function with a bathtub shape
    if t<1:
        return 2*(1-t)
    elif t<3:
        return 0.0
    else:
        return 2*np.sqrt(t-3)
def new_Fdot(y,t):    
    return (1-y)*new_h(t)
t_max=8
time=np.linspace(0.0,t_max,1000)
Finit=0.0
new_F=odeint(new_Fdot,Finit,time)
mean_2=cal_mean(new_F)
print('new E[T]:',mean_2)
# plt.plot(time,list(map(new_h,time)))
# plt.text(4,h(4)+0.5, r'$h(t)$',fontsize=24) #Plots labels in the graph
# plt.text(4,0.5, r'$F(t)$',fontsize=24) 

# plt.plot(time,F)
# plt.title('failure rate function $h$ and associated CDF, $F$')
# plt.axis(ymin=0,ymax=2.0)
# plt.ylabel('$h(t), F(t)$',fontsize=20)
# plt.xlabel('$t$',fontsize=20)
# Out:
# E[T]: 2.6565242200520487
# new E[T]: 1.5504448592454447

# %% [markdown]
# __Answer:__ (Your answer here):
# The E[T] will decrease if the failure rate funtion is double.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 1</SPAN>**

# %% [markdown]
# ## Evolutionary games (replicator dynamics):

# %% [markdown]
# Consider a population of individuals, where each individual is of some type.  Suppose individuals have occasional pairwise encounters.  During an encounter the two individuals involved play a two player symmetric game in which the strategies are the types of the individuals.   As a result of the encounter, each of the two individuals produces a number of offspring of its same type, with the number being determined by a fitess table or, equivalently, a fitness matrix.   For example, consider a population of crickets such that each cricket is either small or large.   If two small crickets meet each other then they each spawn five more small crickets.  If a small cricket encounters a large cricket then the small cricket spawns one more small cricket and the large cricket spawns eight new large crickets.   If two large crickets meet then each of them spawns three new large crickets.  We can summarize these outcomes using the following table:
# $$\begin{array}{c|cc}  & small & large  \\ \hline
#     small & 5 & 1  \\
#     large & 8 & 3
#     \end{array}$$
# or by a fitness matrix
# $$F=\left( \begin{array}{cc}  5 & 1 \\ 8 & 3  \end{array}\right).$$
# Associating 0 with "small" and 1 with "large,"  we see that if a type i individual encounters a type j individual, then the type i individual spawns F[i,j] new individuals of type i, and the type j individual spawns F[j,i] new individuals of type j. Below is a stochastic simulation for this game where we start with a population of four small crickets and four large crickets. It may be a useful exercise for you to think of how the values for $a$ and $b$ were created.

# %%
# Stochastic simulation of replicator dynamics for cricket game

F=np.array([[5,1],[8,3]])  # fitness matrix

n=np.array([4,4])  #[number of small crickets, number of large crickets], initialized
print ("                                   State      Fractions of each type")
print ("Initially                        ", n, "      ", n/1./np.sum(n))

T = 10000 #total number of encounters

for k in range(T):   # k tracks number of encounters
    a=n[0]*(n[0]-1.0)/((n[0]+n[1])*(n[0]+n[1]-1))  # probability both players are type 0
    b=2*n[0]*n[1]/((n[0]+n[1])*(n[0]+n[1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n+=[2*F[0,0],0]
        print ("Round",k+1,"two small crickets meet ", n, n/1./np.sum(n))
    elif a<U<=a+b:
        n+=[F[0,1],F[1,0]]
        print ("Round",k+1,"a small meets a large   ", n, n/1./np.sum(n))
    else:
        n+=[0,2*F[1,1]]
        print ("Round",k+1,"two large crickets meet ", n, n/1./np.sum(n))
# Out:
#                                    State      Fractions of each type
# Initially                         [4 4]        [0.5 0.5]
# Round 1 a small meets a large    [ 5 12] [0.29411765 0.70588235]
# Round 2 a small meets a large    [ 6 20] [0.23076923 0.76923077]
# Round 3 two large crickets meet  [ 6 26] [0.1875 0.8125]
# Round 4 two large crickets meet  [ 6 32] [0.15789474 0.84210526]
# Round 5 a small meets a large    [ 7 40] [0.14893617 0.85106383]
# Round 6 two large crickets meet  [ 7 46] [0.13207547 0.86792453]
# Round 7 a small meets a large    [ 8 54] [0.12903226 0.87096774]
# Round 8 a small meets a large    [ 9 62] [0.12676056 0.87323944]
# Round 9 two large crickets meet  [ 9 68] [0.11688312 0.88311688]
# Round 10 two large crickets meet  [ 9 74] [0.10843373 0.89156627]
# Round 11 a small meets a large    [10 82] [0.10869565 0.89130435]
# Round 12 two large crickets meet  [10 88] [0.10204082 0.89795918]
# Round 13 two large crickets meet  [10 94] [0.09615385 0.90384615]
# Round 14 two large crickets meet  [ 10 100] [0.09090909 0.90909091]
# Round 15 a small meets a large    [ 11 108] [0.09243697 0.90756303]
# Round 16 a small meets a large    [ 12 116] [0.09375 0.90625]
# Round 17 a small meets a large    [ 13 124] [0.09489051 0.90510949]
# Round 18 two large crickets meet  [ 13 130] [0.09090909 0.90909091]
# Round 19 two large crickets meet  [ 13 136] [0.08724832 0.91275168]
# Round 20 two large crickets meet  [ 13 142] [0.08387097 0.91612903]
# Round 21 two large crickets meet  [ 13 148] [0.08074534 0.91925466]
# Round 22 two large crickets meet  [ 13 154] [0.07784431 0.92215569]
# Round 23 two large crickets meet  [ 13 160] [0.07514451 0.92485549]
# Round 24 two large crickets meet  [ 13 166] [0.0726257 0.9273743]
# Round 25 two large crickets meet  [ 13 172] [0.07027027 0.92972973]
# Round 26 a small meets a large    [ 14 180] [0.07216495 0.92783505]
# Round 27 two large crickets meet  [ 14 186] [0.07 0.93]
# Round 28 two large crickets meet  [ 14 192] [0.06796117 0.93203883]
# Round 29 two large crickets meet  [ 14 198] [0.06603774 0.93396226]
# Round 30 two large crickets meet  [ 14 204] [0.06422018 0.93577982]
# Round 31 two large crickets meet  [ 14 210] [0.0625 0.9375]
# Round 32 a small meets a large    [ 15 218] [0.06437768 0.93562232]
# Round 33 two large crickets meet  [ 15 224] [0.06276151 0.93723849]
# Round 34 two large crickets meet  [ 15 230] [0.06122449 0.93877551]
# Round 35 two large crickets meet  [ 15 236] [0.05976096 0.94023904]
# Round 36 two large crickets meet  [ 15 242] [0.05836576 0.94163424]
# Round 37 two large crickets meet  [ 15 248] [0.05703422 0.94296578]
# Round 38 a small meets a large    [ 16 256] [0.05882353 0.94117647]
# Round 39 two large crickets meet  [ 16 262] [0.05755396 0.94244604]
# Round 40 a small meets a large    [ 17 270] [0.05923345 0.94076655]
# Round 41 two large crickets meet  [ 17 276] [0.05802048 0.94197952]
# Round 42 two large crickets meet  [ 17 282] [0.05685619 0.94314381]
# Round 43 two large crickets meet  [ 17 288] [0.0557377 0.9442623]
# Round 44 two large crickets meet  [ 17 294] [0.05466238 0.94533762]
# Round 45 two large crickets meet  [ 17 300] [0.05362776 0.94637224]
# Round 46 two large crickets meet  [ 17 306] [0.05263158 0.94736842]
# Round 47 two large crickets meet  [ 17 312] [0.05167173 0.94832827]
# Round 48 two large crickets meet  [ 17 318] [0.05074627 0.94925373]
# Round 49 two large crickets meet  [ 17 324] [0.04985337 0.95014663]
# Round 50 two large crickets meet  [ 17 330] [0.04899135 0.95100865]
# Round 51 two large crickets meet  [ 17 336] [0.04815864 0.95184136]
# Round 52 two large crickets meet  [ 17 342] [0.04735376 0.95264624]
# Round 53 a small meets a large    [ 18 350] [0.04891304 0.95108696]
# Round 54 a small meets a large    [ 19 358] [0.05039788 0.94960212]
# Round 55 two large crickets meet  [ 19 364] [0.04960836 0.95039164]
# Round 56 two large crickets meet  [ 19 370] [0.04884319 0.95115681]
# Round 57 two large crickets meet  [ 19 376] [0.04810127 0.95189873]
# Round 58 a small meets a large    [ 20 384] [0.04950495 0.95049505]
# Round 59 two large crickets meet  [ 20 390] [0.04878049 0.95121951]
# Round 60 two large crickets meet  [ 20 396] [0.04807692 0.95192308]
# Round 61 two large crickets meet  [ 20 402] [0.04739336 0.95260664]
# Round 62 a small meets a large    [ 21 410] [0.0487239 0.9512761]
# Round 63 two large crickets meet  [ 21 416] [0.04805492 0.95194508]
# Round 64 two large crickets meet  [ 21 422] [0.04740406 0.95259594]
# Round 65 two large crickets meet  [ 21 428] [0.0467706 0.9532294]
# Round 66 a small meets a large    [ 22 436] [0.04803493 0.95196507]
# Round 67 two large crickets meet  [ 22 442] [0.04741379 0.95258621]
# Round 68 a small meets a large    [ 23 450] [0.04862579 0.95137421]
# Round 69 two large crickets meet  [ 23 456] [0.0480167 0.9519833]
# Round 70 two large crickets meet  [ 23 462] [0.04742268 0.95257732]
# Round 71 a small meets a large    [ 24 470] [0.048583 0.951417]
# Round 72 two large crickets meet  [ 24 476] [0.048 0.952]
# Round 73 two large crickets meet  [ 24 482] [0.04743083 0.95256917]
# Round 74 two large crickets meet  [ 24 488] [0.046875 0.953125]
# Round 75 two large crickets meet  [ 24 494] [0.04633205 0.95366795]
# Round 76 two large crickets meet  [ 24 500] [0.04580153 0.95419847]
# Round 77 two large crickets meet  [ 24 506] [0.04528302 0.95471698]
# Round 78 two large crickets meet  [ 24 512] [0.04477612 0.95522388]
# Round 79 two large crickets meet  [ 24 518] [0.04428044 0.95571956]
# Round 80 two large crickets meet  [ 24 524] [0.04379562 0.95620438]
# Round 81 two large crickets meet  [ 24 530] [0.0433213 0.9566787]
# Round 82 a small meets a large    [ 25 538] [0.04440497 0.95559503]
# Round 83 two large crickets meet  [ 25 544] [0.04393673 0.95606327]
# Round 84 two large crickets meet  [ 25 550] [0.04347826 0.95652174]
# Round 85 two large crickets meet  [ 25 556] [0.04302926 0.95697074]
# Round 86 two large crickets meet  [ 25 562] [0.04258944 0.95741056]
# Round 87 two large crickets meet  [ 25 568] [0.04215852 0.95784148]
# Round 88 two large crickets meet  [ 25 574] [0.04173623 0.95826377]
# Round 89 two large crickets meet  [ 25 580] [0.04132231 0.95867769]
# Round 90 two large crickets meet  [ 25 586] [0.04091653 0.95908347]
# Round 91 a small meets a large    [ 26 594] [0.04193548 0.95806452]
# Round 92 two large crickets meet  [ 26 600] [0.04153355 0.95846645]
# Round 93 two large crickets meet  [ 26 606] [0.04113924 0.95886076]
# Round 94 two large crickets meet  [ 26 612] [0.04075235 0.95924765]
# Round 95 two large crickets meet  [ 26 618] [0.04037267 0.95962733]
# Round 96 two large crickets meet  [ 26 624] [0.04 0.96]
# Round 97 two large crickets meet  [ 26 630] [0.03963415 0.96036585]
# Round 98 two large crickets meet  [ 26 636] [0.03927492 0.96072508]
# Round 99 two large crickets meet  [ 26 642] [0.03892216 0.96107784]
# Round 100 two large crickets meet  [ 26 648] [0.03857567 0.96142433]
# Round 101 a small meets a large    [ 27 656] [0.03953148 0.96046852]
# Round 102 two large crickets meet  [ 27 662] [0.03918723 0.96081277]
# Round 103 two large crickets meet  [ 27 668] [0.03884892 0.96115108]
# Round 104 two large crickets meet  [ 27 674] [0.03851641 0.96148359]
# Round 105 two large crickets meet  [ 27 680] [0.03818953 0.96181047]
# Round 106 two large crickets meet  [ 27 686] [0.03786816 0.96213184]
# Round 107 two large crickets meet  [ 27 692] [0.03755216 0.96244784]
# Round 108 two large crickets meet  [ 27 698] [0.03724138 0.96275862]
# Round 109 two large crickets meet  [ 27 704] [0.0369357 0.9630643]
# Round 110 two large crickets meet  [ 27 710] [0.03663501 0.96336499]
# Round 111 two large crickets meet  [ 27 716] [0.03633917 0.96366083]
# Round 112 two large crickets meet  [ 27 722] [0.03604806 0.96395194]
# Round 113 two large crickets meet  [ 27 728] [0.03576159 0.96423841]
# Round 114 two large crickets meet  [ 27 734] [0.03547963 0.96452037]
# Round 115 two large crickets meet  [ 27 740] [0.03520209 0.96479791]
# Round 116 two large crickets meet  [ 27 746] [0.03492885 0.96507115]
# Round 117 two large crickets meet  [ 27 752] [0.03465982 0.96534018]
# Round 118 two large crickets meet  [ 27 758] [0.0343949 0.9656051]
# Round 119 two large crickets meet  [ 27 764] [0.03413401 0.96586599]
# Round 120 two large crickets meet  [ 27 770] [0.03387704 0.96612296]
# Round 121 two large crickets meet  [ 27 776] [0.03362391 0.96637609]
# Round 122 two large crickets meet  [ 27 782] [0.03337454 0.96662546]
# Round 123 two large crickets meet  [ 27 788] [0.03312883 0.96687117]
# Round 124 two large crickets meet  [ 27 794] [0.03288672 0.96711328]
# Round 125 two large crickets meet  [ 27 800] [0.03264813 0.96735187]
# Round 126 two large crickets meet  [ 27 806] [0.03241297 0.96758703]
# Round 127 two large crickets meet  [ 27 812] [0.03218117 0.96781883]
# Round 128 two large crickets meet  [ 27 818] [0.03195266 0.96804734]
# Round 129 a small meets a large    [ 28 826] [0.03278689 0.96721311]
# Round 130 two large crickets meet  [ 28 832] [0.03255814 0.96744186]
# Round 131 two large crickets meet  [ 28 838] [0.03233256 0.96766744]
# Round 132 two large crickets meet  [ 28 844] [0.03211009 0.96788991]
# Round 133 two large crickets meet  [ 28 850] [0.03189066 0.96810934]
# Round 134 two large crickets meet  [ 28 856] [0.03167421 0.96832579]
# Round 135 two large crickets meet  [ 28 862] [0.03146067 0.96853933]
# Round 136 two large crickets meet  [ 28 868] [0.03125 0.96875]
# Round 137 two large crickets meet  [ 28 874] [0.03104213 0.96895787]
# Round 138 two large crickets meet  [ 28 880] [0.030837 0.969163]
# Round 139 two large crickets meet  [ 28 886] [0.03063457 0.96936543]
# Round 140 two large crickets meet  [ 28 892] [0.03043478 0.96956522]
# Round 141 a small meets a large    [ 29 900] [0.03121636 0.96878364]
# Round 142 two large crickets meet  [ 29 906] [0.03101604 0.96898396]
# Round 143 two large crickets meet  [ 29 912] [0.03081828 0.96918172]
# Round 144 two large crickets meet  [ 29 918] [0.03062302 0.96937698]
# Round 145 two large crickets meet  [ 29 924] [0.03043022 0.96956978]
# Round 146 two large crickets meet  [ 29 930] [0.03023983 0.96976017]
# Round 147 two large crickets meet  [ 29 936] [0.03005181 0.96994819]
# Round 148 two large crickets meet  [ 29 942] [0.02986612 0.97013388]
# Round 149 two large crickets meet  [ 29 948] [0.0296827 0.9703173]
# Round 150 two large crickets meet  [ 29 954] [0.02950153 0.97049847]
# Round 151 two large crickets meet  [ 29 960] [0.02932255 0.97067745]
# Round 152 two large crickets meet  [ 29 966] [0.02914573 0.97085427]
# Round 153 two large crickets meet  [ 29 972] [0.02897103 0.97102897]
# Round 154 two large crickets meet  [ 29 978] [0.02879841 0.97120159]
# Round 155 two large crickets meet  [ 29 984] [0.02862784 0.97137216]
# Round 156 two large crickets meet  [ 29 990] [0.02845927 0.97154073]
# Round 157 two large crickets meet  [ 29 996] [0.02829268 0.97170732]
# Round 158 two large crickets meet  [  29 1002] [0.02812803 0.97187197]
# Round 159 two large crickets meet  [  29 1008] [0.02796528 0.97203472]
# Round 160 two large crickets meet  [  29 1014] [0.02780441 0.97219559]
# Round 161 two large crickets meet  [  29 1020] [0.02764538 0.97235462]
# Round 162 two large crickets meet  [  29 1026] [0.02748815 0.97251185]
# Round 163 two large crickets meet  [  29 1032] [0.0273327 0.9726673]
# Round 164 two large crickets meet  [  29 1038] [0.02717901 0.97282099]
# Round 165 two large crickets meet  [  29 1044] [0.02702703 0.97297297]
# Round 166 two large crickets meet  [  29 1050] [0.02687674 0.97312326]
# Round 167 two large crickets meet  [  29 1056] [0.02672811 0.97327189]
# Round 168 a small meets a large    [  30 1064] [0.0274223 0.9725777]
# Round 169 two large crickets meet  [  30 1070] [0.02727273 0.97272727]
# Round 170 two large crickets meet  [  30 1076] [0.02712477 0.97287523]
# Round 171 two large crickets meet  [  30 1082] [0.02697842 0.97302158]
# Round 172 two large crickets meet  [  30 1088] [0.02683363 0.97316637]
# Round 173 two large crickets meet  [  30 1094] [0.02669039 0.97330961]
# Round 174 two large crickets meet  [  30 1100] [0.02654867 0.97345133]
# Round 175 two large crickets meet  [  30 1106] [0.02640845 0.97359155]
# Round 176 two large crickets meet  [  30 1112] [0.0262697 0.9737303]
# Round 177 two large crickets meet  [  30 1118] [0.0261324 0.9738676]
# Round 178 two large crickets meet  [  30 1124] [0.02599653 0.97400347]
# Round 179 two large crickets meet  [  30 1130] [0.02586207 0.97413793]
# Round 180 two large crickets meet  [  30 1136] [0.02572899 0.97427101]
# Round 181 two large crickets meet  [  30 1142] [0.02559727 0.97440273]
# Round 182 two large crickets meet  [  30 1148] [0.02546689 0.97453311]
# Round 183 two large crickets meet  [  30 1154] [0.02533784 0.97466216]
# Round 184 two large crickets meet  [  30 1160] [0.02521008 0.97478992]
# Round 185 two large crickets meet  [  30 1166] [0.02508361 0.97491639]
# Round 186 two large crickets meet  [  30 1172] [0.0249584 0.9750416]
# Round 187 two large crickets meet  [  30 1178] [0.02483444 0.97516556]
# Round 188 two large crickets meet  [  30 1184] [0.0247117 0.9752883]
# Round 189 two large crickets meet  [  30 1190] [0.02459016 0.97540984]
# Round 190 two large crickets meet  [  30 1196] [0.02446982 0.97553018]
# Round 191 two large crickets meet  [  30 1202] [0.02435065 0.97564935]
# Round 192 two large crickets meet  [  30 1208] [0.02423263 0.97576737]
# Round 193 two large crickets meet  [  30 1214] [0.02411576 0.97588424]
# Round 194 a small meets a large    [  31 1222] [0.02474062 0.97525938]
# Round 195 two large crickets meet  [  31 1228] [0.02462272 0.97537728]
# Round 196 two large crickets meet  [  31 1234] [0.02450593 0.97549407]
# Round 197 two large crickets meet  [  31 1240] [0.02439024 0.97560976]
# Round 198 two large crickets meet  [  31 1246] [0.02427565 0.97572435]
# Round 199 two large crickets meet  [  31 1252] [0.02416212 0.97583788]
# Round 200 two large crickets meet  [  31 1258] [0.02404965 0.97595035]
# Round 201 two large crickets meet  [  31 1264] [0.02393822 0.97606178]
# Round 202 two large crickets meet  [  31 1270] [0.02382782 0.97617218]
# Round 203 two large crickets meet  [  31 1276] [0.02371844 0.97628156]
# Round 204 two large crickets meet  [  31 1282] [0.02361005 0.97638995]
# Round 205 two large crickets meet  [  31 1288] [0.02350265 0.97649735]
# Round 206 two large crickets meet  [  31 1294] [0.02339623 0.97660377]
# Round 207 two large crickets meet  [  31 1300] [0.02329076 0.97670924]
# Round 208 two large crickets meet  [  31 1306] [0.02318624 0.97681376]
# Round 209 two large crickets meet  [  31 1312] [0.02308265 0.97691735]
# Round 210 two large crickets meet  [  31 1318] [0.02297999 0.97702001]
# Round 211 two large crickets meet  [  31 1324] [0.02287823 0.97712177]
# Round 212 two large crickets meet  [  31 1330] [0.02277737 0.97722263]
# Round 213 two large crickets meet  [  31 1336] [0.0226774 0.9773226]
# Round 214 two large crickets meet  [  31 1342] [0.0225783 0.9774217]
# Round 215 two large crickets meet  [  31 1348] [0.02248006 0.97751994]
# Round 216 two large crickets meet  [  31 1354] [0.02238267 0.97761733]
# Round 217 two large crickets meet  [  31 1360] [0.02228613 0.97771387]
# Round 218 two large crickets meet  [  31 1366] [0.02219041 0.97780959]
# Round 219 two large crickets meet  [  31 1372] [0.02209551 0.97790449]
# Round 220 two large crickets meet  [  31 1378] [0.02200142 0.97799858]
# Round 221 two large crickets meet  [  31 1384] [0.02190813 0.97809187]
# Round 222 two large crickets meet  [  31 1390] [0.02181562 0.97818438]
# Round 223 two large crickets meet  [  31 1396] [0.0217239 0.9782761]
# Round 224 two large crickets meet  [  31 1402] [0.02163294 0.97836706]
# Round 225 two large crickets meet  [  31 1408] [0.02154274 0.97845726]
# Round 226 two large crickets meet  [  31 1414] [0.02145329 0.97854671]
# Round 227 two large crickets meet  [  31 1420] [0.02136458 0.97863542]
# Round 228 two large crickets meet  [  31 1426] [0.0212766 0.9787234]
# Round 229 two large crickets meet  [  31 1432] [0.02118934 0.97881066]
# Round 230 two large crickets meet  [  31 1438] [0.02110279 0.97889721]
# Round 231 a small meets a large    [  32 1446] [0.02165088 0.97834912]
# Round 232 two large crickets meet  [  32 1452] [0.02156334 0.97843666]
# Round 233 two large crickets meet  [  32 1458] [0.02147651 0.97852349]
# Round 234 two large crickets meet  [  32 1464] [0.02139037 0.97860963]
# Round 235 two large crickets meet  [  32 1470] [0.02130493 0.97869507]
# Round 236 two large crickets meet  [  32 1476] [0.02122016 0.97877984]
# Round 237 two large crickets meet  [  32 1482] [0.02113606 0.97886394]
# Round 238 two large crickets meet  [  32 1488] [0.02105263 0.97894737]
# Round 239 two large crickets meet  [  32 1494] [0.02096986 0.97903014]
# Round 240 two large crickets meet  [  32 1500] [0.02088773 0.97911227]
# Round 241 two large crickets meet  [  32 1506] [0.02080624 0.97919376]
# Round 242 two large crickets meet  [  32 1512] [0.02072539 0.97927461]
# Round 243 two large crickets meet  [  32 1518] [0.02064516 0.97935484]
# Round 244 a small meets a large    [  33 1526] [0.02116742 0.97883258]
# Round 245 two large crickets meet  [  33 1532] [0.02108626 0.97891374]
# Round 246 two large crickets meet  [  33 1538] [0.02100573 0.97899427]
# Round 247 two large crickets meet  [  33 1544] [0.02092581 0.97907419]
# Round 248 two large crickets meet  [  33 1550] [0.02084649 0.97915351]
# Round 249 two large crickets meet  [  33 1556] [0.02076778 0.97923222]
# Round 250 two large crickets meet  [  33 1562] [0.02068966 0.97931034]
# Round 251 two large crickets meet  [  33 1568] [0.02061212 0.97938788]
# Round 252 two large crickets meet  [  33 1574] [0.02053516 0.97946484]
# Round 253 two large crickets meet  [  33 1580] [0.02045877 0.97954123]
# Round 254 two large crickets meet  [  33 1586] [0.02038295 0.97961705]
# Round 255 two large crickets meet  [  33 1592] [0.02030769 0.97969231]
# Round 256 two large crickets meet  [  33 1598] [0.02023299 0.97976701]
# Round 257 two large crickets meet  [  33 1604] [0.02015883 0.97984117]
# Round 258 two large crickets meet  [  33 1610] [0.02008521 0.97991479]
# Round 259 two large crickets meet  [  33 1616] [0.02001213 0.97998787]
# Round 260 two large crickets meet  [  33 1622] [0.01993958 0.98006042]
# Round 261 two large crickets meet  [  33 1628] [0.01986755 0.98013245]
# Round 262 two large crickets meet  [  33 1634] [0.01979604 0.98020396]
# Round 263 two large crickets meet  [  33 1640] [0.01972504 0.98027496]
# Round 264 two large crickets meet  [  33 1646] [0.01965456 0.98034544]
# Round 265 two large crickets meet  [  33 1652] [0.01958457 0.98041543]
# Round 266 two large crickets meet  [  33 1658] [0.01951508 0.98048492]
# Round 267 two large crickets meet  [  33 1664] [0.01944608 0.98055392]
# Round 268 two large crickets meet  [  33 1670] [0.01937757 0.98062243]
# Round 269 two large crickets meet  [  33 1676] [0.01930954 0.98069046]
# Round 270 two large crickets meet  [  33 1682] [0.01924198 0.98075802]
# Round 271 two large crickets meet  [  33 1688] [0.0191749 0.9808251]
# Round 272 two large crickets meet  [  33 1694] [0.01910828 0.98089172]
# Round 273 two large crickets meet  [  33 1700] [0.01904212 0.98095788]
# Round 274 two large crickets meet  [  33 1706] [0.01897642 0.98102358]
# Round 275 two large crickets meet  [  33 1712] [0.01891117 0.98108883]
# Round 276 two large crickets meet  [  33 1718] [0.01884637 0.98115363]
# Round 277 two large crickets meet  [  33 1724] [0.01878201 0.98121799]
# Round 278 two large crickets meet  [  33 1730] [0.01871809 0.98128191]
# Round 279 two large crickets meet  [  33 1736] [0.01865461 0.98134539]
# Round 280 two large crickets meet  [  33 1742] [0.01859155 0.98140845]
# Round 281 two large crickets meet  [  33 1748] [0.01852892 0.98147108]
# Round 282 two large crickets meet  [  33 1754] [0.0184667 0.9815333]
# Round 283 two large crickets meet  [  33 1760] [0.01840491 0.98159509]
# Round 284 two large crickets meet  [  33 1766] [0.01834352 0.98165648]
# Round 285 two large crickets meet  [  33 1772] [0.01828255 0.98171745]
# Round 286 two large crickets meet  [  33 1778] [0.01822198 0.98177802]
# Round 287 two large crickets meet  [  33 1784] [0.01816181 0.98183819]
# Round 288 two large crickets meet  [  33 1790] [0.01810203 0.98189797]
# Round 289 two large crickets meet  [  33 1796] [0.01804265 0.98195735]
# Round 290 two large crickets meet  [  33 1802] [0.01798365 0.98201635]
# Round 291 two large crickets meet  [  33 1808] [0.01792504 0.98207496]
# Round 292 a small meets a large    [  34 1816] [0.01837838 0.98162162]
# Round 293 two large crickets meet  [  34 1822] [0.01831897 0.98168103]
# Round 294 two large crickets meet  [  34 1828] [0.01825994 0.98174006]
# Round 295 two large crickets meet  [  34 1834] [0.01820128 0.98179872]
# Round 296 two large crickets meet  [  34 1840] [0.01814301 0.98185699]
# Round 297 a small meets a large    [  35 1848] [0.01858736 0.98141264]
# Round 298 two large crickets meet  [  35 1854] [0.01852832 0.98147168]
# Round 299 two large crickets meet  [  35 1860] [0.01846966 0.98153034]
# Round 300 two large crickets meet  [  35 1866] [0.01841136 0.98158864]
# Round 301 two large crickets meet  [  35 1872] [0.01835343 0.98164657]
# Round 302 two large crickets meet  [  35 1878] [0.01829587 0.98170413]
# Round 303 two large crickets meet  [  35 1884] [0.01823867 0.98176133]
# Round 304 two large crickets meet  [  35 1890] [0.01818182 0.98181818]
# Round 305 two large crickets meet  [  35 1896] [0.01812532 0.98187468]
# Round 306 two large crickets meet  [  35 1902] [0.01806918 0.98193082]
# Round 307 two large crickets meet  [  35 1908] [0.01801338 0.98198662]
# Round 308 two large crickets meet  [  35 1914] [0.01795793 0.98204207]
# Round 309 two large crickets meet  [  35 1920] [0.01790281 0.98209719]
# Round 310 two large crickets meet  [  35 1926] [0.01784804 0.98215196]
# Round 311 two large crickets meet  [  35 1932] [0.01779359 0.98220641]
# Round 312 two large crickets meet  [  35 1938] [0.01773948 0.98226052]
# Round 313 two large crickets meet  [  35 1944] [0.0176857 0.9823143]
# Round 314 two large crickets meet  [  35 1950] [0.01763224 0.98236776]
# Round 315 two large crickets meet  [  35 1956] [0.01757911 0.98242089]
# Round 316 two large crickets meet  [  35 1962] [0.01752629 0.98247371]
# Round 317 two large crickets meet  [  35 1968] [0.01747379 0.98252621]
# Round 318 two large crickets meet  [  35 1974] [0.0174216 0.9825784]
# Round 319 two large crickets meet  [  35 1980] [0.01736973 0.98263027]
# Round 320 two large crickets meet  [  35 1986] [0.01731816 0.98268184]
# Round 321 two large crickets meet  [  35 1992] [0.0172669 0.9827331]
# Round 322 two large crickets meet  [  35 1998] [0.01721594 0.98278406]
# Round 323 two large crickets meet  [  35 2004] [0.01716528 0.98283472]
# Round 324 two large crickets meet  [  35 2010] [0.01711491 0.98288509]
# Round 325 two large crickets meet  [  35 2016] [0.01706485 0.98293515]
# Round 326 two large crickets meet  [  35 2022] [0.01701507 0.98298493]
# Round 327 two large crickets meet  [  35 2028] [0.01696558 0.98303442]
# Round 328 two large crickets meet  [  35 2034] [0.01691638 0.98308362]
# Round 329 two large crickets meet  [  35 2040] [0.01686747 0.98313253]
# Round 330 two large crickets meet  [  35 2046] [0.01681884 0.98318116]
# Round 331 two large crickets meet  [  35 2052] [0.01677048 0.98322952]
# Round 332 two large crickets meet  [  35 2058] [0.01672241 0.98327759]
# Round 333 two large crickets meet  [  35 2064] [0.01667461 0.98332539]
# Round 334 two large crickets meet  [  35 2070] [0.01662708 0.98337292]
# Round 335 two large crickets meet  [  35 2076] [0.01657982 0.98342018]
# Round 336 two large crickets meet  [  35 2082] [0.01653283 0.98346717]
# Round 337 two large crickets meet  [  35 2088] [0.0164861 0.9835139]
# Round 338 two large crickets meet  [  35 2094] [0.01643964 0.98356036]
# Round 339 two large crickets meet  [  35 2100] [0.01639344 0.98360656]
# Round 340 two large crickets meet  [  35 2106] [0.0163475 0.9836525]
# Round 341 two large crickets meet  [  35 2112] [0.01630182 0.98369818]
# Round 342 two large crickets meet  [  35 2118] [0.01625639 0.98374361]
# Round 343 two large crickets meet  [  35 2124] [0.01621121 0.98378879]
# Round 344 two large crickets meet  [  35 2130] [0.01616628 0.98383372]
# Round 345 two large crickets meet  [  35 2136] [0.0161216 0.9838784]
# Round 346 two large crickets meet  [  35 2142] [0.01607717 0.98392283]
# Round 347 two large crickets meet  [  35 2148] [0.01603298 0.98396702]
# Round 348 two large crickets meet  [  35 2154] [0.01598904 0.98401096]
# Round 349 two large crickets meet  [  35 2160] [0.01594533 0.98405467]
# Round 350 two large crickets meet  [  35 2166] [0.01590186 0.98409814]
# Round 351 two large crickets meet  [  35 2172] [0.01585863 0.98414137]
# Round 352 two large crickets meet  [  35 2178] [0.01581563 0.98418437]
# Round 353 two large crickets meet  [  35 2184] [0.01577287 0.98422713]
# Round 354 two large crickets meet  [  35 2190] [0.01573034 0.98426966]
# Round 355 two large crickets meet  [  35 2196] [0.01568803 0.98431197]
# Round 356 two large crickets meet  [  35 2202] [0.01564595 0.98435405]
# Round 357 two large crickets meet  [  35 2208] [0.0156041 0.9843959]
# Round 358 two large crickets meet  [  35 2214] [0.01556247 0.98443753]
# Round 359 two large crickets meet  [  35 2220] [0.01552106 0.98447894]
# Round 360 two large crickets meet  [  35 2226] [0.01547988 0.98452012]
# Round 361 two large crickets meet  [  35 2232] [0.01543891 0.98456109]
# Round 362 two large crickets meet  [  35 2238] [0.01539815 0.98460185]
# Round 363 two large crickets meet  [  35 2244] [0.01535761 0.98464239]
# Round 364 two large crickets meet  [  35 2250] [0.01531729 0.98468271]
# Round 365 two large crickets meet  [  35 2256] [0.01527717 0.98472283]
# Round 366 two large crickets meet  [  35 2262] [0.01523727 0.98476273]
# Round 367 two large crickets meet  [  35 2268] [0.01519757 0.98480243]
# Round 368 two large crickets meet  [  35 2274] [0.01515808 0.98484192]
# Round 369 two large crickets meet  [  35 2280] [0.01511879 0.98488121]
# Round 370 two large crickets meet  [  35 2286] [0.01507971 0.98492029]
# Round 371 two large crickets meet  [  35 2292] [0.01504083 0.98495917]
# Round 372 two large crickets meet  [  35 2298] [0.01500214 0.98499786]
# Round 373 two large crickets meet  [  35 2304] [0.01496366 0.98503634]
# Round 374 two large crickets meet  [  35 2310] [0.01492537 0.98507463]
# Round 375 two large crickets meet  [  35 2316] [0.01488728 0.98511272]
# Round 376 two large crickets meet  [  35 2322] [0.01484938 0.98515062]
# Round 377 two large crickets meet  [  35 2328] [0.01481168 0.98518832]
# Round 378 two large crickets meet  [  35 2334] [0.01477417 0.98522583]
# Round 379 two large crickets meet  [  35 2340] [0.01473684 0.98526316]
# Round 380 two large crickets meet  [  35 2346] [0.01469971 0.98530029]
# Round 381 two large crickets meet  [  35 2352] [0.01466276 0.98533724]
# Round 382 two large crickets meet  [  35 2358] [0.01462599 0.98537401]
# Round 383 two large crickets meet  [  35 2364] [0.01458941 0.98541059]
# Round 384 two large crickets meet  [  35 2370] [0.01455301 0.98544699]
# Round 385 two large crickets meet  [  35 2376] [0.0145168 0.9854832]
# Round 386 two large crickets meet  [  35 2382] [0.01448076 0.98551924]
# Round 387 two large crickets meet  [  35 2388] [0.0144449 0.9855551]
# Round 388 two large crickets meet  [  35 2394] [0.01440922 0.98559078]
# Round 389 two large crickets meet  [  35 2400] [0.01437372 0.98562628]
# Round 390 two large crickets meet  [  35 2406] [0.01433839 0.98566161]
# Round 391 two large crickets meet  [  35 2412] [0.01430323 0.98569677]
# Round 392 two large crickets meet  [  35 2418] [0.01426824 0.98573176]
# Round 393 two large crickets meet  [  35 2424] [0.01423343 0.98576657]
# Round 394 two large crickets meet  [  35 2430] [0.01419878 0.98580122]
# Round 395 two large crickets meet  [  35 2436] [0.01416431 0.98583569]
# Round 396 two large crickets meet  [  35 2442] [0.01413 0.98587]
# Round 397 two large crickets meet  [  35 2448] [0.01409585 0.98590415]
# Round 398 two large crickets meet  [  35 2454] [0.01406187 0.98593813]
# Round 399 two large crickets meet  [  35 2460] [0.01402806 0.98597194]
# Round 400 two large crickets meet  [  35 2466] [0.0139944 0.9860056]
# Round 401 two large crickets meet  [  35 2472] [0.01396091 0.98603909]
# Round 402 a small meets a large    [  36 2480] [0.01430843 0.98569157]
# Round 403 two large crickets meet  [  36 2486] [0.01427439 0.98572561]
# Round 404 two large crickets meet  [  36 2492] [0.01424051 0.98575949]
# Round 405 two large crickets meet  [  36 2498] [0.01420679 0.98579321]
# Round 406 two large crickets meet  [  36 2504] [0.01417323 0.98582677]
# Round 407 two large crickets meet  [  36 2510] [0.01413983 0.98586017]
# Round 408 two large crickets meet  [  36 2516] [0.01410658 0.98589342]
# Round 409 two large crickets meet  [  36 2522] [0.01407349 0.98592651]
# Round 410 two large crickets meet  [  36 2528] [0.01404056 0.98595944]
# Round 411 a small meets a large    [  37 2536] [0.0143801 0.9856199]
# Round 412 two large crickets meet  [  37 2542] [0.01434665 0.98565335]
# Round 413 two large crickets meet  [  37 2548] [0.01431335 0.98568665]
# Round 414 two large crickets meet  [  37 2554] [0.0142802 0.9857198]
# Round 415 two large crickets meet  [  37 2560] [0.01424721 0.98575279]
# Round 416 two large crickets meet  [  37 2566] [0.01421437 0.98578563]
# Round 417 two large crickets meet  [  37 2572] [0.01418168 0.98581832]
# Round 418 two large crickets meet  [  37 2578] [0.01414914 0.98585086]
# Round 419 two large crickets meet  [  37 2584] [0.01411675 0.98588325]
# Round 420 two large crickets meet  [  37 2590] [0.01408451 0.98591549]
# Round 421 two large crickets meet  [  37 2596] [0.01405241 0.98594759]
# Round 422 two large crickets meet  [  37 2602] [0.01402046 0.98597954]
# Round 423 two large crickets meet  [  37 2608] [0.01398866 0.98601134]
# Round 424 two large crickets meet  [  37 2614] [0.013957 0.986043]
# Round 425 two large crickets meet  [  37 2620] [0.01392548 0.98607452]
# Round 426 two large crickets meet  [  37 2626] [0.0138941 0.9861059]
# Round 427 two large crickets meet  [  37 2632] [0.01386287 0.98613713]
# Round 428 two large crickets meet  [  37 2638] [0.01383178 0.98616822]
# Round 429 two large crickets meet  [  37 2644] [0.01380082 0.98619918]
# Round 430 two large crickets meet  [  37 2650] [0.01377 0.98623]
# Round 431 two large crickets meet  [  37 2656] [0.01373932 0.98626068]
# Round 432 two large crickets meet  [  37 2662] [0.01370878 0.98629122]
# Round 433 two large crickets meet  [  37 2668] [0.01367837 0.98632163]
# Round 434 two large crickets meet  [  37 2674] [0.0136481 0.9863519]
# Round 435 two large crickets meet  [  37 2680] [0.01361796 0.98638204]
# Round 436 two large crickets meet  [  37 2686] [0.01358795 0.98641205]
# Round 437 two large crickets meet  [  37 2692] [0.01355808 0.98644192]
# Round 438 two large crickets meet  [  37 2698] [0.01352834 0.98647166]
# Round 439 two large crickets meet  [  37 2704] [0.01349872 0.98650128]
# Round 440 two large crickets meet  [  37 2710] [0.01346924 0.98653076]
# Round 441 two large crickets meet  [  37 2716] [0.01343988 0.98656012]
# Round 442 two large crickets meet  [  37 2722] [0.01341066 0.98658934]
# Round 443 two large crickets meet  [  37 2728] [0.01338156 0.98661844]
# Round 444 two large crickets meet  [  37 2734] [0.01335258 0.98664742]
# Round 445 two large crickets meet  [  37 2740] [0.01332373 0.98667627]
# Round 446 two large crickets meet  [  37 2746] [0.01329501 0.98670499]
# Round 447 two large crickets meet  [  37 2752] [0.0132664 0.9867336]
# Round 448 two large crickets meet  [  37 2758] [0.01323792 0.98676208]
# Round 449 two large crickets meet  [  37 2764] [0.01320957 0.98679043]
# Round 450 two large crickets meet  [  37 2770] [0.01318133 0.98681867]
# Round 451 two large crickets meet  [  37 2776] [0.01315322 0.98684678]
# Round 452 two large crickets meet  [  37 2782] [0.01312522 0.98687478]
# Round 453 two large crickets meet  [  37 2788] [0.01309735 0.98690265]
# Round 454 two large crickets meet  [  37 2794] [0.01306959 0.98693041]
# Round 455 two large crickets meet  [  37 2800] [0.01304195 0.98695805]
# Round 456 two large crickets meet  [  37 2806] [0.01301442 0.98698558]
# Round 457 two large crickets meet  [  37 2812] [0.01298701 0.98701299]
# Round 458 two large crickets meet  [  37 2818] [0.01295972 0.98704028]
# Round 459 two large crickets meet  [  37 2824] [0.01293254 0.98706746]
# Round 460 two large crickets meet  [  37 2830] [0.01290548 0.98709452]
# Round 461 two large crickets meet  [  37 2836] [0.01287852 0.98712148]
# Round 462 two large crickets meet  [  37 2842] [0.01285168 0.98714832]
# Round 463 two large crickets meet  [  37 2848] [0.01282496 0.98717504]
# Round 464 two large crickets meet  [  37 2854] [0.01279834 0.98720166]
# Round 465 a small meets a large    [  38 2862] [0.01310345 0.98689655]
# Round 466 two large crickets meet  [  38 2868] [0.01307639 0.98692361]
# Round 467 two large crickets meet  [  38 2874] [0.01304945 0.98695055]
# Round 468 two large crickets meet  [  38 2880] [0.01302262 0.98697738]
# Round 469 two large crickets meet  [  38 2886] [0.0129959 0.9870041]
# Round 470 two large crickets meet  [  38 2892] [0.01296928 0.98703072]
# Round 471 two large crickets meet  [  38 2898] [0.01294278 0.98705722]
# Round 472 two large crickets meet  [  38 2904] [0.01291638 0.98708362]
# Round 473 two large crickets meet  [  38 2910] [0.01289009 0.98710991]
# Round 474 two large crickets meet  [  38 2916] [0.01286391 0.98713609]
# Round 475 two large crickets meet  [  38 2922] [0.01283784 0.98716216]
# Round 476 two large crickets meet  [  38 2928] [0.01281187 0.98718813]
# Round 477 two large crickets meet  [  38 2934] [0.012786 0.987214]
# Round 478 two large crickets meet  [  38 2940] [0.01276024 0.98723976]
# Round 479 two large crickets meet  [  38 2946] [0.01273458 0.98726542]
# Round 480 two large crickets meet  [  38 2952] [0.01270903 0.98729097]
# Round 481 two large crickets meet  [  38 2958] [0.01268358 0.98731642]
# Round 482 two large crickets meet  [  38 2964] [0.01265823 0.98734177]
# Round 483 two large crickets meet  [  38 2970] [0.01263298 0.98736702]
# Round 484 two large crickets meet  [  38 2976] [0.01260783 0.98739217]
# Round 485 two large crickets meet  [  38 2982] [0.01258278 0.98741722]
# Round 486 two large crickets meet  [  38 2988] [0.01255783 0.98744217]
# Round 487 two large crickets meet  [  38 2994] [0.01253298 0.98746702]
# Round 488 two large crickets meet  [  38 3000] [0.01250823 0.98749177]
# Round 489 two large crickets meet  [  38 3006] [0.01248357 0.98751643]
# Round 490 two large crickets meet  [  38 3012] [0.01245902 0.98754098]
# Round 491 two large crickets meet  [  38 3018] [0.01243455 0.98756545]
# Round 492 two large crickets meet  [  38 3024] [0.01241019 0.98758981]
# Round 493 two large crickets meet  [  38 3030] [0.01238592 0.98761408]
# Round 494 two large crickets meet  [  38 3036] [0.01236174 0.98763826]
# Round 495 two large crickets meet  [  38 3042] [0.01233766 0.98766234]
# Round 496 two large crickets meet  [  38 3048] [0.01231367 0.98768633]
# Round 497 two large crickets meet  [  38 3054] [0.01228978 0.98771022]
# Round 498 two large crickets meet  [  38 3060] [0.01226598 0.98773402]
# Round 499 two large crickets meet  [  38 3066] [0.01224227 0.98775773]
# Round 500 two large crickets meet  [  38 3072] [0.01221865 0.98778135]
# Round 501 two large crickets meet  [  38 3078] [0.01219512 0.98780488]
# Round 502 two large crickets meet  [  38 3084] [0.01217168 0.98782832]
# Round 503 two large crickets meet  [  38 3090] [0.01214834 0.98785166]
# Round 504 two large crickets meet  [  38 3096] [0.01212508 0.98787492]
# Round 505 two large crickets meet  [  38 3102] [0.01210191 0.98789809]
# Round 506 two large crickets meet  [  38 3108] [0.01207883 0.98792117]
# Round 507 two large crickets meet  [  38 3114] [0.01205584 0.98794416]
# Round 508 two large crickets meet  [  38 3120] [0.01203293 0.98796707]
# Round 509 two large crickets meet  [  38 3126] [0.01201011 0.98798989]
# Round 510 two large crickets meet  [  38 3132] [0.01198738 0.98801262]
# Round 511 two large crickets meet  [  38 3138] [0.01196474 0.98803526]
# Round 512 two large crickets meet  [  38 3144] [0.01194217 0.98805783]
# Round 513 two large crickets meet  [  38 3150] [0.0119197 0.9880803]
# Round 514 a small meets a large    [  39 3158] [0.01219894 0.98780106]
# Round 515 two large crickets meet  [  39 3164] [0.01217608 0.98782392]
# Round 516 two large crickets meet  [  39 3170] [0.01215332 0.98784668]
# Round 517 two large crickets meet  [  39 3176] [0.01213064 0.98786936]
# Round 518 two large crickets meet  [  39 3182] [0.01210804 0.98789196]
# Round 519 two large crickets meet  [  39 3188] [0.01208553 0.98791447]
# Round 520 two large crickets meet  [  39 3194] [0.0120631 0.9879369]
# Round 521 two large crickets meet  [  39 3200] [0.01204075 0.98795925]
# Round 522 two large crickets meet  [  39 3206] [0.01201849 0.98798151]
# Round 523 a small meets a large    [  40 3214] [0.01229256 0.98770744]
# Round 524 two large crickets meet  [  40 3220] [0.01226994 0.98773006]
# Round 525 two large crickets meet  [  40 3226] [0.0122474 0.9877526]
# Round 526 two large crickets meet  [  40 3232] [0.01222494 0.98777506]
# Round 527 two large crickets meet  [  40 3238] [0.01220256 0.98779744]
# Round 528 two large crickets meet  [  40 3244] [0.01218027 0.98781973]
# Round 529 two large crickets meet  [  40 3250] [0.01215805 0.98784195]
# Round 530 two large crickets meet  [  40 3256] [0.01213592 0.98786408]
# Round 531 two large crickets meet  [  40 3262] [0.01211387 0.98788613]
# Round 532 two large crickets meet  [  40 3268] [0.0120919 0.9879081]
# Round 533 two large crickets meet  [  40 3274] [0.01207001 0.98792999]
# Round 534 two large crickets meet  [  40 3280] [0.01204819 0.98795181]
# Round 535 two large crickets meet  [  40 3286] [0.01202646 0.98797354]
# Round 536 two large crickets meet  [  40 3292] [0.0120048 0.9879952]
# Round 537 two large crickets meet  [  40 3298] [0.01198322 0.98801678]
# Round 538 a small meets a large    [  41 3306] [0.01224978 0.98775022]
# Round 539 two large crickets meet  [  41 3312] [0.01222786 0.98777214]
# Round 540 two large crickets meet  [  41 3318] [0.01220601 0.98779399]
# Round 541 two large crickets meet  [  41 3324] [0.01218425 0.98781575]
# Round 542 two large crickets meet  [  41 3330] [0.01216256 0.98783744]
# Round 543 two large crickets meet  [  41 3336] [0.01214095 0.98785905]
# Round 544 two large crickets meet  [  41 3342] [0.01211942 0.98788058]
# Round 545 two large crickets meet  [  41 3348] [0.01209796 0.98790204]
# Round 546 two large crickets meet  [  41 3354] [0.01207658 0.98792342]
# Round 547 two large crickets meet  [  41 3360] [0.01205528 0.98794472]
# Round 548 two large crickets meet  [  41 3366] [0.01203405 0.98796595]
# Round 549 two large crickets meet  [  41 3372] [0.01201289 0.98798711]
# Round 550 two large crickets meet  [  41 3378] [0.01199181 0.98800819]
# Round 551 two large crickets meet  [  41 3384] [0.0119708 0.9880292]
# Round 552 two large crickets meet  [  41 3390] [0.01194987 0.98805013]
# Round 553 two large crickets meet  [  41 3396] [0.01192901 0.98807099]
# Round 554 two large crickets meet  [  41 3402] [0.01190822 0.98809178]
# Round 555 two large crickets meet  [  41 3408] [0.0118875 0.9881125]
# Round 556 two large crickets meet  [  41 3414] [0.01186686 0.98813314]
# Round 557 two large crickets meet  [  41 3420] [0.01184629 0.98815371]
# Round 558 two large crickets meet  [  41 3426] [0.01182579 0.98817421]
# Round 559 two large crickets meet  [  41 3432] [0.01180536 0.98819464]
# Round 560 two large crickets meet  [  41 3438] [0.011785 0.988215]
# Round 561 two large crickets meet  [  41 3444] [0.01176471 0.98823529]
# Round 562 two large crickets meet  [  41 3450] [0.01174449 0.98825551]
# Round 563 two large crickets meet  [  41 3456] [0.01172434 0.98827566]
# Round 564 two large crickets meet  [  41 3462] [0.01170425 0.98829575]
# Round 565 two large crickets meet  [  41 3468] [0.01168424 0.98831576]
# Round 566 two large crickets meet  [  41 3474] [0.0116643 0.9883357]
# Round 567 two large crickets meet  [  41 3480] [0.01164442 0.98835558]
# Round 568 two large crickets meet  [  41 3486] [0.01162461 0.98837539]
# Round 569 two large crickets meet  [  41 3492] [0.01160487 0.98839513]
# Round 570 two large crickets meet  [  41 3498] [0.01158519 0.98841481]
# Round 571 two large crickets meet  [  41 3504] [0.01156559 0.98843441]
# Round 572 two large crickets meet  [  41 3510] [0.01154604 0.98845396]
# Round 573 two large crickets meet  [  41 3516] [0.01152657 0.98847343]
# Round 574 a small meets a large    [  42 3524] [0.0117779 0.9882221]
# Round 575 two large crickets meet  [  42 3530] [0.01175812 0.98824188]
# Round 576 two large crickets meet  [  42 3536] [0.0117384 0.9882616]
# Round 577 two large crickets meet  [  42 3542] [0.01171875 0.98828125]
# Round 578 two large crickets meet  [  42 3548] [0.01169916 0.98830084]
# Round 579 two large crickets meet  [  42 3554] [0.01167964 0.98832036]
# Round 580 two large crickets meet  [  42 3560] [0.01166019 0.98833981]
# Round 581 two large crickets meet  [  42 3566] [0.0116408 0.9883592]
# Round 582 two large crickets meet  [  42 3572] [0.01162147 0.98837853]
# Round 583 two large crickets meet  [  42 3578] [0.01160221 0.98839779]
# Round 584 two large crickets meet  [  42 3584] [0.01158301 0.98841699]
# Round 585 two large crickets meet  [  42 3590] [0.01156388 0.98843612]
# Round 586 two large crickets meet  [  42 3596] [0.0115448 0.9884552]
# Round 587 a small meets a large    [  43 3604] [0.01179051 0.98820949]
# Round 588 two large crickets meet  [  43 3610] [0.01177115 0.98822885]
# Round 589 two large crickets meet  [  43 3616] [0.01175184 0.98824816]
# Round 590 two large crickets meet  [  43 3622] [0.01173261 0.98826739]
# Round 591 two large crickets meet  [  43 3628] [0.01171343 0.98828657]
# Round 592 two large crickets meet  [  43 3634] [0.01169432 0.98830568]
# Round 593 two large crickets meet  [  43 3640] [0.01167526 0.98832474]
# Round 594 two large crickets meet  [  43 3646] [0.01165628 0.98834372]
# Round 595 two large crickets meet  [  43 3652] [0.01163735 0.98836265]
# Round 596 two large crickets meet  [  43 3658] [0.01161848 0.98838152]
# Round 597 two large crickets meet  [  43 3664] [0.01159968 0.98840032]
# Round 598 two large crickets meet  [  43 3670] [0.01158093 0.98841907]
# Round 599 two large crickets meet  [  43 3676] [0.01156225 0.98843775]
# Round 600 two large crickets meet  [  43 3682] [0.01154362 0.98845638]
# Round 601 two large crickets meet  [  43 3688] [0.01152506 0.98847494]
# Round 602 two large crickets meet  [  43 3694] [0.01150656 0.98849344]
# Round 603 two large crickets meet  [  43 3700] [0.01148811 0.98851189]
# Round 604 two large crickets meet  [  43 3706] [0.01146973 0.98853027]
# Round 605 two large crickets meet  [  43 3712] [0.0114514 0.9885486]
# Round 606 two large crickets meet  [  43 3718] [0.01143313 0.98856687]
# Round 607 two large crickets meet  [  43 3724] [0.01141492 0.98858508]
# Round 608 two large crickets meet  [  43 3730] [0.01139677 0.98860323]
# Round 609 two large crickets meet  [  43 3736] [0.01137867 0.98862133]
# Round 610 two large crickets meet  [  43 3742] [0.01136063 0.98863937]
# Round 611 two large crickets meet  [  43 3748] [0.01134265 0.98865735]
# Round 612 two large crickets meet  [  43 3754] [0.01132473 0.98867527]
# Round 613 two large crickets meet  [  43 3760] [0.01130686 0.98869314]
# Round 614 two large crickets meet  [  43 3766] [0.01128905 0.98871095]
# Round 615 two large crickets meet  [  43 3772] [0.0112713 0.9887287]
# Round 616 two large crickets meet  [  43 3778] [0.0112536 0.9887464]
# Round 617 two large crickets meet  [  43 3784] [0.01123596 0.98876404]
# Round 618 two large crickets meet  [  43 3790] [0.01121837 0.98878163]
# Round 619 two large crickets meet  [  43 3796] [0.01120083 0.98879917]
# Round 620 two large crickets meet  [  43 3802] [0.01118336 0.98881664]
# Round 621 two large crickets meet  [  43 3808] [0.01116593 0.98883407]
# Round 622 two large crickets meet  [  43 3814] [0.01114856 0.98885144]
# Round 623 two large crickets meet  [  43 3820] [0.01113125 0.98886875]
# Round 624 two large crickets meet  [  43 3826] [0.01111398 0.98888602]
# Round 625 two large crickets meet  [  43 3832] [0.01109677 0.98890323]
# Round 626 two large crickets meet  [  43 3838] [0.01107962 0.98892038]
# Round 627 two large crickets meet  [  43 3844] [0.01106252 0.98893748]
# Round 628 two large crickets meet  [  43 3850] [0.01104547 0.98895453]
# Round 629 two large crickets meet  [  43 3856] [0.01102847 0.98897153]
# Round 630 two large crickets meet  [  43 3862] [0.01101152 0.98898848]
# Round 631 two large crickets meet  [  43 3868] [0.01099463 0.98900537]
# Round 632 two large crickets meet  [  43 3874] [0.01097779 0.98902221]
# Round 633 two large crickets meet  [  43 3880] [0.010961 0.989039]
# Round 634 two large crickets meet  [  43 3886] [0.01094426 0.98905574]
# Round 635 two large crickets meet  [  43 3892] [0.01092757 0.98907243]
# Round 636 two large crickets meet  [  43 3898] [0.01091094 0.98908906]
# Round 637 two large crickets meet  [  43 3904] [0.01089435 0.98910565]
# Round 638 two large crickets meet  [  43 3910] [0.01087781 0.98912219]
# Round 639 two large crickets meet  [  43 3916] [0.01086133 0.98913867]
# Round 640 two large crickets meet  [  43 3922] [0.01084489 0.98915511]
# Round 641 two large crickets meet  [  43 3928] [0.01082851 0.98917149]
# Round 642 two large crickets meet  [  43 3934] [0.01081217 0.98918783]
# Round 643 two large crickets meet  [  43 3940] [0.01079588 0.98920412]
# Round 644 two large crickets meet  [  43 3946] [0.01077964 0.98922036]
# Round 645 two large crickets meet  [  43 3952] [0.01076345 0.98923655]
# Round 646 two large crickets meet  [  43 3958] [0.01074731 0.98925269]
# Round 647 two large crickets meet  [  43 3964] [0.01073122 0.98926878]
# Round 648 two large crickets meet  [  43 3970] [0.01071518 0.98928482]
# Round 649 two large crickets meet  [  43 3976] [0.01069918 0.98930082]
# Round 650 two large crickets meet  [  43 3982] [0.01068323 0.98931677]
# Round 651 two large crickets meet  [  43 3988] [0.01066733 0.98933267]
# Round 652 two large crickets meet  [  43 3994] [0.01065147 0.98934853]
# Round 653 two large crickets meet  [  43 4000] [0.01063567 0.98936433]
# Round 654 two large crickets meet  [  43 4006] [0.01061991 0.98938009]
# Round 655 two large crickets meet  [  43 4012] [0.01060419 0.98939581]
# Round 656 two large crickets meet  [  43 4018] [0.01058852 0.98941148]
# Round 657 two large crickets meet  [  43 4024] [0.0105729 0.9894271]
# Round 658 two large crickets meet  [  43 4030] [0.01055733 0.98944267]
# Round 659 two large crickets meet  [  43 4036] [0.0105418 0.9894582]
# Round 660 two large crickets meet  [  43 4042] [0.01052632 0.98947368]
# Round 661 two large crickets meet  [  43 4048] [0.01051088 0.98948912]
# Round 662 two large crickets meet  [  43 4054] [0.01049548 0.98950452]
# Round 663 two large crickets meet  [  43 4060] [0.01048014 0.98951986]
# Round 664 two large crickets meet  [  43 4066] [0.01046483 0.98953517]
# Round 665 two large crickets meet  [  43 4072] [0.01044957 0.98955043]
# Round 666 two large crickets meet  [  43 4078] [0.01043436 0.98956564]
# Round 667 two large crickets meet  [  43 4084] [0.01041919 0.98958081]
# Round 668 two large crickets meet  [  43 4090] [0.01040406 0.98959594]
# Round 669 two large crickets meet  [  43 4096] [0.01038898 0.98961102]
# Round 670 two large crickets meet  [  43 4102] [0.01037394 0.98962606]
# Round 671 two large crickets meet  [  43 4108] [0.01035895 0.98964105]
# Round 672 two large crickets meet  [  43 4114] [0.010344 0.989656]
# Round 673 a small meets a large    [  44 4122] [0.01056169 0.98943831]
# Round 674 two large crickets meet  [  44 4128] [0.0105465 0.9894535]
# Round 675 two large crickets meet  [  44 4134] [0.01053135 0.98946865]
# Round 676 two large crickets meet  [  44 4140] [0.01051625 0.98948375]
# Round 677 two large crickets meet  [  44 4146] [0.01050119 0.98949881]
# Round 678 two large crickets meet  [  44 4152] [0.01048618 0.98951382]
# Round 679 two large crickets meet  [  44 4158] [0.0104712 0.9895288]
# Round 680 two large crickets meet  [  44 4164] [0.01045627 0.98954373]
# Round 681 two large crickets meet  [  44 4170] [0.01044139 0.98955861]
# Round 682 two large crickets meet  [  44 4176] [0.01042654 0.98957346]
# Round 683 two large crickets meet  [  44 4182] [0.01041174 0.98958826]
# ...
# Round 9785 two large crickets meet  [   94 58894] [0.00159354 0.99840646]
# Round 9786 two large crickets meet  [   94 58900] [0.00159338 0.99840662]
# Round 9787 two large crickets meet  [   94 58906] [0.00159322 0.99840678]
# Round 9788 two large crickets meet  [   94 58912] [0.00159306 0.99840694]
# Round 9789 two large crickets meet  [   94 58918] [0.0015929 0.9984071]
# Round 9790 two large crickets meet  [   94 58924] [0.00159273 0.99840727]
# Round 9791 two large crickets meet  [   94 58930] [0.00159257 0.99840743]
# Round 9792 two large crickets meet  [   94 58936] [0.00159241 0.99840759]
# Round 9793 two large crickets meet  [   94 58942] [0.00159225 0.99840775]
# Round 9794 two large crickets meet  [   94 58948] [0.00159209 0.99840791]
# Round 9795 two large crickets meet  [   94 58954] [0.00159193 0.99840807]
# Round 9796 two large crickets meet  [   94 58960] [0.00159176 0.99840824]
# Round 9797 two large crickets meet  [   94 58966] [0.0015916 0.9984084]
# Round 9798 two large crickets meet  [   94 58972] [0.00159144 0.99840856]
# Round 9799 two large crickets meet  [   94 58978] [0.00159128 0.99840872]
# Round 9800 two large crickets meet  [   94 58984] [0.00159112 0.99840888]
# Round 9801 two large crickets meet  [   94 58990] [0.00159096 0.99840904]
# Round 9802 two large crickets meet  [   94 58996] [0.00159079 0.99840921]
# Round 9803 two large crickets meet  [   94 59002] [0.00159063 0.99840937]
# Round 9804 two large crickets meet  [   94 59008] [0.00159047 0.99840953]
# Round 9805 two large crickets meet  [   94 59014] [0.00159031 0.99840969]
# Round 9806 two large crickets meet  [   94 59020] [0.00159015 0.99840985]
# Round 9807 two large crickets meet  [   94 59026] [0.00158999 0.99841001]
# Round 9808 two large crickets meet  [   94 59032] [0.00158983 0.99841017]
# Round 9809 two large crickets meet  [   94 59038] [0.00158966 0.99841034]
# Round 9810 two large crickets meet  [   94 59044] [0.0015895 0.9984105]
# Round 9811 two large crickets meet  [   94 59050] [0.00158934 0.99841066]
# Round 9812 two large crickets meet  [   94 59056] [0.00158918 0.99841082]
# Round 9813 two large crickets meet  [   94 59062] [0.00158902 0.99841098]
# Round 9814 two large crickets meet  [   94 59068] [0.00158886 0.99841114]
# Round 9815 two large crickets meet  [   94 59074] [0.0015887 0.9984113]
# Round 9816 two large crickets meet  [   94 59080] [0.00158854 0.99841146]
# Round 9817 two large crickets meet  [   94 59086] [0.00158837 0.99841163]
# Round 9818 two large crickets meet  [   94 59092] [0.00158821 0.99841179]
# Round 9819 two large crickets meet  [   94 59098] [0.00158805 0.99841195]
# Round 9820 two large crickets meet  [   94 59104] [0.00158789 0.99841211]
# Round 9821 two large crickets meet  [   94 59110] [0.00158773 0.99841227]
# Round 9822 two large crickets meet  [   94 59116] [0.00158757 0.99841243]
# Round 9823 two large crickets meet  [   94 59122] [0.00158741 0.99841259]
# Round 9824 two large crickets meet  [   94 59128] [0.00158725 0.99841275]
# Round 9825 two large crickets meet  [   94 59134] [0.00158709 0.99841291]
# Round 9826 two large crickets meet  [   94 59140] [0.00158693 0.99841307]
# Round 9827 two large crickets meet  [   94 59146] [0.00158677 0.99841323]
# Round 9828 two large crickets meet  [   94 59152] [0.00158661 0.99841339]
# Round 9829 two large crickets meet  [   94 59158] [0.00158644 0.99841356]
# Round 9830 two large crickets meet  [   94 59164] [0.00158628 0.99841372]
# Round 9831 two large crickets meet  [   94 59170] [0.00158612 0.99841388]
# Round 9832 two large crickets meet  [   94 59176] [0.00158596 0.99841404]
# Round 9833 two large crickets meet  [   94 59182] [0.0015858 0.9984142]
# Round 9834 two large crickets meet  [   94 59188] [0.00158564 0.99841436]
# Round 9835 two large crickets meet  [   94 59194] [0.00158548 0.99841452]
# Round 9836 two large crickets meet  [   94 59200] [0.00158532 0.99841468]
# Round 9837 two large crickets meet  [   94 59206] [0.00158516 0.99841484]
# Round 9838 two large crickets meet  [   94 59212] [0.001585 0.998415]
# Round 9839 two large crickets meet  [   94 59218] [0.00158484 0.99841516]
# Round 9840 two large crickets meet  [   94 59224] [0.00158468 0.99841532]
# Round 9841 two large crickets meet  [   94 59230] [0.00158452 0.99841548]
# Round 9842 two large crickets meet  [   94 59236] [0.00158436 0.99841564]
# Round 9843 two large crickets meet  [   94 59242] [0.0015842 0.9984158]
# Round 9844 two large crickets meet  [   94 59248] [0.00158404 0.99841596]
# Round 9845 two large crickets meet  [   94 59254] [0.00158388 0.99841612]
# Round 9846 two large crickets meet  [   94 59260] [0.00158372 0.99841628]
# Round 9847 two large crickets meet  [   94 59266] [0.00158356 0.99841644]
# Round 9848 two large crickets meet  [   94 59272] [0.0015834 0.9984166]
# Round 9849 two large crickets meet  [   94 59278] [0.00158324 0.99841676]
# Round 9850 two large crickets meet  [   94 59284] [0.00158308 0.99841692]
# Round 9851 two large crickets meet  [   94 59290] [0.00158292 0.99841708]
# Round 9852 two large crickets meet  [   94 59296] [0.00158276 0.99841724]
# Round 9853 two large crickets meet  [   94 59302] [0.0015826 0.9984174]
# Round 9854 two large crickets meet  [   94 59308] [0.00158244 0.99841756]
# Round 9855 two large crickets meet  [   94 59314] [0.00158228 0.99841772]
# Round 9856 two large crickets meet  [   94 59320] [0.00158212 0.99841788]
# Round 9857 two large crickets meet  [   94 59326] [0.00158196 0.99841804]
# Round 9858 two large crickets meet  [   94 59332] [0.0015818 0.9984182]
# Round 9859 two large crickets meet  [   94 59338] [0.00158164 0.99841836]
# Round 9860 two large crickets meet  [   94 59344] [0.00158148 0.99841852]
# Round 9861 two large crickets meet  [   94 59350] [0.00158132 0.99841868]
# Round 9862 two large crickets meet  [   94 59356] [0.00158116 0.99841884]
# Round 9863 two large crickets meet  [   94 59362] [0.001581 0.998419]
# Round 9864 two large crickets meet  [   94 59368] [0.00158084 0.99841916]
# Round 9865 two large crickets meet  [   94 59374] [0.00158068 0.99841932]
# Round 9866 two large crickets meet  [   94 59380] [0.00158052 0.99841948]
# Round 9867 two large crickets meet  [   94 59386] [0.00158036 0.99841964]
# Round 9868 two large crickets meet  [   94 59392] [0.0015802 0.9984198]
# Round 9869 two large crickets meet  [   94 59398] [0.00158004 0.99841996]
# Round 9870 two large crickets meet  [   94 59404] [0.00157989 0.99842011]
# Round 9871 two large crickets meet  [   94 59410] [0.00157973 0.99842027]
# Round 9872 two large crickets meet  [   94 59416] [0.00157957 0.99842043]
# Round 9873 two large crickets meet  [   94 59422] [0.00157941 0.99842059]
# Round 9874 two large crickets meet  [   94 59428] [0.00157925 0.99842075]
# Round 9875 two large crickets meet  [   94 59434] [0.00157909 0.99842091]
# Round 9876 two large crickets meet  [   94 59440] [0.00157893 0.99842107]
# Round 9877 two large crickets meet  [   94 59446] [0.00157877 0.99842123]
# Round 9878 two large crickets meet  [   94 59452] [0.00157861 0.99842139]
# Round 9879 two large crickets meet  [   94 59458] [0.00157845 0.99842155]
# Round 9880 two large crickets meet  [   94 59464] [0.00157829 0.99842171]
# Round 9881 two large crickets meet  [   94 59470] [0.00157813 0.99842187]
# Round 9882 two large crickets meet  [   94 59476] [0.00157798 0.99842202]
# Round 9883 two large crickets meet  [   94 59482] [0.00157782 0.99842218]
# Round 9884 two large crickets meet  [   94 59488] [0.00157766 0.99842234]
# Round 9885 two large crickets meet  [   94 59494] [0.0015775 0.9984225]
# Round 9886 two large crickets meet  [   94 59500] [0.00157734 0.99842266]
# Round 9887 two large crickets meet  [   94 59506] [0.00157718 0.99842282]
# Round 9888 two large crickets meet  [   94 59512] [0.00157702 0.99842298]
# Round 9889 two large crickets meet  [   94 59518] [0.00157686 0.99842314]
# Round 9890 two large crickets meet  [   94 59524] [0.00157671 0.99842329]
# Round 9891 two large crickets meet  [   94 59530] [0.00157655 0.99842345]
# Round 9892 two large crickets meet  [   94 59536] [0.00157639 0.99842361]
# Round 9893 two large crickets meet  [   94 59542] [0.00157623 0.99842377]
# Round 9894 two large crickets meet  [   94 59548] [0.00157607 0.99842393]
# Round 9895 two large crickets meet  [   94 59554] [0.00157591 0.99842409]
# Round 9896 two large crickets meet  [   94 59560] [0.00157575 0.99842425]
# Round 9897 two large crickets meet  [   94 59566] [0.0015756 0.9984244]
# Round 9898 two large crickets meet  [   94 59572] [0.00157544 0.99842456]
# Round 9899 two large crickets meet  [   94 59578] [0.00157528 0.99842472]
# Round 9900 two large crickets meet  [   94 59584] [0.00157512 0.99842488]
# Round 9901 two large crickets meet  [   94 59590] [0.00157496 0.99842504]
# Round 9902 two large crickets meet  [   94 59596] [0.0015748 0.9984252]
# Round 9903 two large crickets meet  [   94 59602] [0.00157464 0.99842536]
# Round 9904 two large crickets meet  [   94 59608] [0.00157449 0.99842551]
# Round 9905 two large crickets meet  [   94 59614] [0.00157433 0.99842567]
# Round 9906 two large crickets meet  [   94 59620] [0.00157417 0.99842583]
# Round 9907 two large crickets meet  [   94 59626] [0.00157401 0.99842599]
# Round 9908 two large crickets meet  [   94 59632] [0.00157385 0.99842615]
# Round 9909 two large crickets meet  [   94 59638] [0.0015737 0.9984263]
# Round 9910 two large crickets meet  [   94 59644] [0.00157354 0.99842646]
# Round 9911 two large crickets meet  [   94 59650] [0.00157338 0.99842662]
# Round 9912 two large crickets meet  [   94 59656] [0.00157322 0.99842678]
# Round 9913 two large crickets meet  [   94 59662] [0.00157306 0.99842694]
# Round 9914 two large crickets meet  [   94 59668] [0.00157291 0.99842709]
# Round 9915 two large crickets meet  [   94 59674] [0.00157275 0.99842725]
# Round 9916 two large crickets meet  [   94 59680] [0.00157259 0.99842741]
# Round 9917 two large crickets meet  [   94 59686] [0.00157243 0.99842757]
# Round 9918 two large crickets meet  [   94 59692] [0.00157227 0.99842773]
# Round 9919 two large crickets meet  [   94 59698] [0.00157212 0.99842788]
# Round 9920 two large crickets meet  [   94 59704] [0.00157196 0.99842804]
# Round 9921 two large crickets meet  [   94 59710] [0.0015718 0.9984282]
# Round 9922 two large crickets meet  [   94 59716] [0.00157164 0.99842836]
# Round 9923 two large crickets meet  [   94 59722] [0.00157149 0.99842851]
# Round 9924 two large crickets meet  [   94 59728] [0.00157133 0.99842867]
# Round 9925 two large crickets meet  [   94 59734] [0.00157117 0.99842883]
# Round 9926 two large crickets meet  [   94 59740] [0.00157101 0.99842899]
# Round 9927 two large crickets meet  [   94 59746] [0.00157086 0.99842914]
# Round 9928 two large crickets meet  [   94 59752] [0.0015707 0.9984293]
# Round 9929 two large crickets meet  [   94 59758] [0.00157054 0.99842946]
# Round 9930 two large crickets meet  [   94 59764] [0.00157038 0.99842962]
# Round 9931 two large crickets meet  [   94 59770] [0.00157023 0.99842977]
# Round 9932 two large crickets meet  [   94 59776] [0.00157007 0.99842993]
# Round 9933 two large crickets meet  [   94 59782] [0.00156991 0.99843009]
# Round 9934 two large crickets meet  [   94 59788] [0.00156975 0.99843025]
# Round 9935 two large crickets meet  [   94 59794] [0.0015696 0.9984304]
# Round 9936 two large crickets meet  [   94 59800] [0.00156944 0.99843056]
# Round 9937 two large crickets meet  [   94 59806] [0.00156928 0.99843072]
# Round 9938 two large crickets meet  [   94 59812] [0.00156912 0.99843088]
# Round 9939 two large crickets meet  [   94 59818] [0.00156897 0.99843103]
# Round 9940 two large crickets meet  [   94 59824] [0.00156881 0.99843119]
# Round 9941 two large crickets meet  [   94 59830] [0.00156865 0.99843135]
# Round 9942 two large crickets meet  [   94 59836] [0.0015685 0.9984315]
# Round 9943 two large crickets meet  [   94 59842] [0.00156834 0.99843166]
# Round 9944 two large crickets meet  [   94 59848] [0.00156818 0.99843182]
# Round 9945 two large crickets meet  [   94 59854] [0.00156803 0.99843197]
# Round 9946 two large crickets meet  [   94 59860] [0.00156787 0.99843213]
# Round 9947 two large crickets meet  [   94 59866] [0.00156771 0.99843229]
# Round 9948 two large crickets meet  [   94 59872] [0.00156755 0.99843245]
# Round 9949 two large crickets meet  [   94 59878] [0.0015674 0.9984326]
# Round 9950 two large crickets meet  [   94 59884] [0.00156724 0.99843276]
# Round 9951 two large crickets meet  [   94 59890] [0.00156708 0.99843292]
# Round 9952 two large crickets meet  [   94 59896] [0.00156693 0.99843307]
# Round 9953 two large crickets meet  [   94 59902] [0.00156677 0.99843323]
# Round 9954 two large crickets meet  [   94 59908] [0.00156661 0.99843339]
# Round 9955 two large crickets meet  [   94 59914] [0.00156646 0.99843354]
# Round 9956 two large crickets meet  [   94 59920] [0.0015663 0.9984337]
# Round 9957 two large crickets meet  [   94 59926] [0.00156614 0.99843386]
# Round 9958 two large crickets meet  [   94 59932] [0.00156599 0.99843401]
# Round 9959 a small meets a large    [   95 59940] [0.00158241 0.99841759]
# Round 9960 two large crickets meet  [   95 59946] [0.00158225 0.99841775]
# Round 9961 two large crickets meet  [   95 59952] [0.00158209 0.99841791]
# Round 9962 two large crickets meet  [   95 59958] [0.00158194 0.99841806]
# Round 9963 two large crickets meet  [   95 59964] [0.00158178 0.99841822]
# Round 9964 two large crickets meet  [   95 59970] [0.00158162 0.99841838]
# Round 9965 two large crickets meet  [   95 59976] [0.00158146 0.99841854]
# Round 9966 two large crickets meet  [   95 59982] [0.0015813 0.9984187]
# Round 9967 two large crickets meet  [   95 59988] [0.00158115 0.99841885]
# Round 9968 two large crickets meet  [   95 59994] [0.00158099 0.99841901]
# Round 9969 two large crickets meet  [   95 60000] [0.00158083 0.99841917]
# Round 9970 two large crickets meet  [   95 60006] [0.00158067 0.99841933]
# Round 9971 two large crickets meet  [   95 60012] [0.00158051 0.99841949]
# Round 9972 two large crickets meet  [   95 60018] [0.00158036 0.99841964]
# Round 9973 two large crickets meet  [   95 60024] [0.0015802 0.9984198]
# Round 9974 two large crickets meet  [   95 60030] [0.00158004 0.99841996]
# Round 9975 two large crickets meet  [   95 60036] [0.00157988 0.99842012]
# Round 9976 two large crickets meet  [   95 60042] [0.00157973 0.99842027]
# Round 9977 two large crickets meet  [   95 60048] [0.00157957 0.99842043]
# Round 9978 two large crickets meet  [   95 60054] [0.00157941 0.99842059]
# Round 9979 two large crickets meet  [   95 60060] [0.00157925 0.99842075]
# Round 9980 two large crickets meet  [   95 60066] [0.0015791 0.9984209]
# Round 9981 two large crickets meet  [   95 60072] [0.00157894 0.99842106]
# Round 9982 two large crickets meet  [   95 60078] [0.00157878 0.99842122]
# Round 9983 two large crickets meet  [   95 60084] [0.00157862 0.99842138]
# Round 9984 two large crickets meet  [   95 60090] [0.00157847 0.99842153]
# Round 9985 two large crickets meet  [   95 60096] [0.00157831 0.99842169]
# Round 9986 two large crickets meet  [   95 60102] [0.00157815 0.99842185]
# Round 9987 two large crickets meet  [   95 60108] [0.00157799 0.99842201]
# Round 9988 two large crickets meet  [   95 60114] [0.00157784 0.99842216]
# Round 9989 two large crickets meet  [   95 60120] [0.00157768 0.99842232]
# Round 9990 two large crickets meet  [   95 60126] [0.00157752 0.99842248]
# Round 9991 two large crickets meet  [   95 60132] [0.00157737 0.99842263]
# Round 9992 two large crickets meet  [   95 60138] [0.00157721 0.99842279]
# Round 9993 two large crickets meet  [   95 60144] [0.00157705 0.99842295]
# Round 9994 two large crickets meet  [   95 60150] [0.00157689 0.99842311]
# Round 9995 two large crickets meet  [   95 60156] [0.00157674 0.99842326]
# Round 9996 two large crickets meet  [   95 60162] [0.00157658 0.99842342]
# Round 9997 two large crickets meet  [   95 60168] [0.00157642 0.99842358]
# Round 9998 two large crickets meet  [   95 60174] [0.00157627 0.99842373]
# Round 9999 two large crickets meet  [   95 60180] [0.00157611 0.99842389]
# Round 10000 two large crickets meet  [   95 60186] [0.00157595 0.99842405]

# %% [markdown]
# The above simulation displays, after each encounter, the number of individuals of each type and the fraction of individuals of each type.   Run the simulation multiple times for different initial conditions.
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 2:</SPAN>**  Answer the following questions.   You do not need to provide code for this problem, but explain your answers.
# <ol>
# <li> How quickly does the total population grow if initally all the crickets are small?
# <li> How quickly does the total population grow if initally all the crickets are large?
# <li> Do the fractions converge to a stable equilibrium in which the fractions of both small and large crickets are nonzero? (To explore convergence you may need to increase the number of encounters simulated.)
# </ol>

# %% [markdown]
# __Answer:__ (Your answer here)
#
# Q1: After every encounter there will be 10 more small crickets
#
# Q2: After every encounter there will be 6 more large crickets
#
# Q3: No. The next meet is highly dependent on the current state. That is, our random choice may make a long effect.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 2</SPAN>**

# %% [markdown]
# The code given next is essentially the same as above.  One difference is a time variable is added such that the average rate that an individual cricket has encounters is proportional to the total number of crickets.  This results in exponential growth of the population with time.    Another difference is that population sizes are saved and plotted.

# %%
# Stochastic simulation of replicator dynamics for cricket game
# Time is scaled so contact rate of each individual is one per unit time
# The evolution trajectory is stored an plotted

F=np.array([[5,1],[8,3]])  # fitness matrix
n_max=100  # maximum number of interactions
n=np.zeros((n_max,2),dtype=float)
time=np.zeros(n_max,dtype=float)

n[0,0], n[0,1] = 10,1 # initial [number of small crickets, number of large crickets]

for k in range(n_max-1):
    time[k+1]=time[k]+2.0/sum(n[k,:])   # The 2 is here because two individuals make contact at a time
    a=n[k,0]*(n[k,0]-1.0)/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1))  # probability both players are type 0
    b=2*n[k,0]*n[k,1]/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n[k+1,:]= n[k,:] + [2*F[0,0],0]
    elif a<U<=a+b:
        n[k+1,:]=n[k,:] + [F[0,1],F[1,0]]
    else:
        n[k+1,:]= n[k,:] + [0,2*F[1,1]]
print(time)
plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.text(1.1,n[80,0], r'small',fontsize=14)
plt.text(1.1,n[80,1], r'large',fontsize=14)
plt.xlabel('time')
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (simulation)")
# Out:
# [0.         0.18181818 0.27705628 0.34157241 0.39035289 0.42956858
#  0.46290191 0.49320494 0.51987161 0.54340102 0.56467762 0.58409509
#  0.60244372 0.61983502 0.63636395 0.65211198 0.66671052 0.68069653
#  0.69411935 0.70677758 0.71875363 0.73011726 0.74092807 0.75139928
#  0.76134953 0.77101136 0.78040103 0.78941004 0.79803073 0.8062952
#  0.81435971 0.82214181 0.82966061 0.83690699 0.84392453 0.85079738
#  0.8574419  0.86395656 0.87034634 0.87661593 0.88276977 0.88881207
#  0.89469442 0.90047477 0.90610857 0.91158803 0.91697886 0.92224202
#  0.92742337 0.93252541 0.93751294 0.94237912 0.94717528 0.95185912
#  0.95644628 0.96094066 0.96534595 0.9696656  0.97390289 0.97806089
#  0.98214253 0.98617478 0.99013518 0.99404907 0.99789523 1.00169751
#  1.00543583 1.00913268 1.01278899 1.01638611 1.01994483 1.02344134
#  1.02687776 1.03026186 1.03361194 1.03692869 1.04019666 1.04343291
#  1.0466227  1.04978226 1.05291215 1.05599857 1.05905668 1.06208698
#  1.06508998 1.06805294 1.07097265 1.07385035 1.07670342 1.07951636
#  1.08229413 1.08503762 1.08774765 1.09043582 1.09309186 1.09571653
#  1.0983207  1.1008947  1.10344898 1.10598383]
# Text(0.5, 1.0, 'Numbers of small and large crickets vs. time (simulation)')

# %% [markdown]
# The following code computes the deterministic analog of the cricket evolution.  The basic idea is that if the current population is [n[0], n[1]] then the drift (i.e. the expected rate of increase) of n[0] is n[0]  multiplied by the expected number of small crickets generated by a small cricket if an encounter happens.  That is true because each of the existing small crikets is having encounters at expected rate one.   To calculate the mean number of new small crickets generated by the encounter of a small cricket with a randomly selected other cricket, we use the law of total probability.  The encountered cricket is type zero with probabiity n[0]/(n[0]+n[1]), which results in F[0,0] new crickets of type zero, and the encountered cricket is type one with probability n[1]/(n[0]+n[1]), which results in F[0,1] new crickets of type zero.   Combining we get
# $$
# \dot{n}[0] = n[0]*(F[0,0]*n[0]+F[0,1]*n[1])/(n[0]+n[1])
# $$
# The equation just derived is based on the law of large numbers (LLN).  If the population is fairly large then no one individual plays a major role in the evolution.  Over a small period of time the ratios of small and large crickets is nearly constant, so the number of new crickets of each type in each time slot are nearly independent and identically distributed.   The LLN suggests approximating the sum of number of individuals of each type by the expected numbers of individuals of each type.  That's how we arrive at a deterministic differential equation.
#
# A similar expression holds for the derivative of n[1], and the two equations can be writen in matrix form as
# $$
# \dot{n} = diag(n)*F*n/sum(n)
# $$
# where diag(n) is the diagonal matrix with n[0] and n[1] on the diagonal, and "$*$" represents usual matrix multiplication.   (In the python code below, "$*$" denotes element by element multiplication, which is used instead of creating a diagonal matrix, and np.dot is used for ordinary matrix multiplication.)

# %%
# Deterministic (ODE) replicator dynamics for cricket game
from scipy.integrate import odeint

F=np.array([[5,1],[8,3]])  # fitness matrix

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[10,1]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

n=odeint(f,ninit,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (ode prediction)")
# Out:
# Text(0.5, 1.0, 'Numbers of small and large crickets vs. time (ode prediction)')

# %% [markdown]
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 3:</SPAN>** Run the code above and compare the output to the output of the previous code for stochastic evolutionary dynamics.  Try different intial conditions such as [0,4], [4,0], and [10,1]. Comment on how the result of this compares to our previous simulation. Is the behavior similar?

# %% [markdown]
# __Answer__: (Your answer here)
# If the initial condition is 0,4 or 4,0, the output is the same as the previous code. Because large or small will always be 0. However, if the initial condition is 10,1, things become diffferent. The result of previous code is random if it is executed several time. That is because the next encounter depend on current state, but current state depend on the random number. On the contrary, The code above will always produce same result because it use expectation, not random number.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 3</SPAN>**

# %% [markdown]
# If we let $\theta[0]=\frac{n[0]}{n[0]+n[1]}$ and $\theta[1]=\frac{n[1]}{n[0]+n[1]}$ then the vector $\theta=\binom{\theta[0]}{\theta[1]}$ describes the fractions of the popuation of each type.  It's entries sum to one.  Using the chain rule of calculus we can derive the following differential equation for $\theta$ from the above ode for $n$:
# $$
# \dot{\theta} = diag(\theta) \left( F\theta - \mathbf{1} \theta^T F \theta \right)
# $$
# where $\mathbf{1}$ is the column vector of ones (the derivation is a bit involved, try deriving it by yourself if interested, but it is not required). The two components of the vector $F \theta$ give the average fitness level of small crickets and large crickets, respectively, in an encounter with a cricket selected randomly from the population.   And $\theta^T F \theta$ is the weighted average of that vector, giving the average fitness over all crickets in the population.   Thus, $\theta[0]$ is increasing exactly when the fitness of small crickets is greater than the average fitness.
#
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 4:</SPAN>**
#
# 1. Modify the above code to integrate the equation for the $\theta$ vector to obtain $\theta$ vs. time.
# To check your answer, compare it to what you get by first computing the trajectory of $n$ and then calculating $\theta$ from $n.$  (The code given above for deterministic evolution of n works for any number of types, not just two types. A problem below involves three types of individuals, so it'd be nice if you could implement your code for computing $\theta$ to work for any number of types.) __Be careful when you write your program, since matrix multiplication in Python can be tricky. Understand "$*$" multiplication and np.dot multiplication first. After each small step, debug, confirm, then proceed.__
# 2. Using the fact that $\theta[1]=1-\theta[0],$  a differential equation can be derived for the variable $\theta[0]$ alone.
# Plot the function $h$ on the interval $[0,1]$ such that $\dot{\theta}[0]=h(\theta[0]).$ Note that the horizontal axis of the graph is $\theta$, the vertical axis is $\dot{\theta}$. (You can just do this
# numerically.  It can also be done algebrically; in fact $h$ is a cubic polynomial, but it is a bit complicated to find the polynomial.)
# 3. What are the zeroes of $h$ (those are the equilibrium points of $\theta[0]$)?  Which of those are stable (in the sense that if $\theta[0]$ is slightly moved away from the equilibrium point, it returns to the equilibrium point)?

# %%
# Your code here
from scipy.integrate import odeint

F=np.array([[5,1],[8,3]])  # fitness matrix

def new_f(theta,t):
    return theta*(np.dot(F,theta)-np.dot(np.transpose(theta),np.dot(F,theta)))#(n*np.dot(F,n)/sum(n)/1.)

thetainit=[10/11,1/11]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

n=odeint(new_f,thetainit,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('percentage')
plt.title("percentage of small and large crickets vs. time (ode prediction)")
# Out:
# Text(0.5, 1.0, 'percentage of small and large crickets vs. time (ode prediction)')

# %%
from scipy.integrate import odeint

F=np.array([[5,1],[8,3]])  # fitness matrix

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[10,1]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

n=odeint(f,ninit,time)
print(n)
for i in range(len(n)):
    temp = n[i,0]
    n[i,0] = n[i,0]/(n[i,0]+n[i,1])
    n[i,1] = n[i,1]/(temp+n[i,1])
plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('percentage')
plt.title("percentage of small and large crickets vs. time (ode prediction)")
# Out:
# [[1.00000000e+01 1.00000000e+00]
#  [1.00698470e+01 1.01139257e+00]
#  [1.01401599e+01 1.02291214e+00]
#  ...
#  [1.23451866e+03 5.65083693e+03]
#  [1.23770401e+03 5.68398420e+03]
#  [1.24089400e+03 5.71730529e+03]]
# Text(0.5, 1.0, 'percentage of small and large crickets vs. time (ode prediction)')

# %%
theta0=np.linspace(0,1,100)
dtheta0 = theta0*(5*theta0+1-theta0-(5*theta0**2+9*theta0*(1-theta0)+3*(1-theta0)**2))
plt.plot(theta0,dtheta0)

# %% [markdown]
# __Answer:__ (Your answer here)
# Q1: the result derived by $\theta$ and $n$ are the same

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 4</SPAN>**

# %% [markdown]
# The overall behavior in evolutionary games depends heavily on the fitness matrix $F.$   Another choice of $F$ corresponds to the so-called doves and hawks evolution game, for which the fitness matrix is
# $$\begin{array}{c|cc}  & dove & hawk  \\ \hline
#     dove & 3 & 1  \\
#     hawk & 5 & 0
#     \end{array}$$
# or by a fitness matrix
# $$F=\left( \begin{array}{cc}  3 & 1 \\ 5 & 0  \end{array}\right).$$   Think of the doves and hawks as two types of birds that need to share resources, such as food.  (The hawks are so aggressive that they attack the doves).  A dove has higher fitness, 3, against another dove than against a hawk, 1.  A hawk has a high fitness against a dove (5) but zero fitness against another hawk, because the hawks fight over their resources.
#
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 5:</SPAN>**
#
# 1. Repeat the deterministic (ode) approach above, but now for the doves and hawks evolution game.   You can use either the random or deterministic evolution equations for the numerical analysis.
# 2. Comment and verify your assertions about equilibrium behavior by finding a differential equation for $\theta[0]$ and exploring its equilbrium points and their stability.

# %%
# Your code here
F=np.array([[3,1],[5,0]])  # fitness matrix

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[10,1]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,10, 1000)

n=odeint(f,ninit,time)
print(n)
for i in range(len(n)):
    temp = n[i,0]
    n[i,0] = n[i,0]/(n[i,0]+n[i,1])
    n[i,1] = n[i,1]/(temp+n[i,1])
plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'dove',fontsize=14)
plt.text(1.1,n[800,1], r'hawk',fontsize=14)
plt.ylabel('Fractions')
plt.title("Fractions of dove and hawk vs. time (ode prediction)")
# Out:
# [[1.00000000e+01 1.00000000e+00]
#  [1.02859693e+01 1.04651347e+00]
#  [1.05798102e+01 1.09511122e+00]
#  ...
#  [1.23066636e+09 2.45315582e+09]
#  [1.25138870e+09 2.49451805e+09]
#  [1.27245984e+09 2.53657706e+09]]
# Text(0.5, 1.0, 'Fractions of dove and hawk vs. time (ode prediction)')

# %%
theta=np.linspace(0,1,100)
dtheta = theta*(2*theta+1-(3*theta**2+6*theta*(1-theta)))
plt.plot(theta,dtheta)
plt.xlabel('theta')
plt.ylabel('dtheta')
plt.title("theta vs. dtheta")
# Out:
# Text(0.5, 1.0, 'theta vs. dtheta')

# %% [markdown]
# __Answer__: (Your answer here)

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 5</SPAN>**

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 6:</SPAN>**  Find a 3x3 fitness matrix $F$ and an initial condition for an evolutionary game with three types of individuals such that the solution $\theta$ has a limit cycle, not just converging to a limit point.  Does the limit cycle depend on the intial state for your fitness matrix?
#
# Hint 1: Adapt the code you wrote for Problem 4.
#
# Hint 2: Solve this problem by trial and error, i.e. trying different values of the entries in the fitness matrix. Think of the three types of individuals as three kinds of animals. What kind of relationship among these three animals would likely to cause an oscillating population for each animal?

# %%
# Your code here

# %% [markdown]
# __Answer__: (Your answer here)

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 6</SPAN>**

# %% [markdown]
# For this week's lab, please answer all questions 1-6.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ## Academic Integrity Statement ##
#
# By submitting the lab with this statement, you declare you have written up the lab entirely by yourself, including both code and markdown cells. You also agree that you should not share your code with anyone else. Any violation of the academic integrity requirement may cause an academic integrity report to be filed that could go into your student record. See <a href="https://provost.illinois.edu/policies/policies/academic-integrity/students-quick-reference-guide-to-academic-integrity/">Students' Quick Reference Guide to Academic Integrity</a> for more information.
